# %% [markdown]
# # PPO with MLP - Features

# %%
import numpy as np
import yfinance as yf
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd
import math
import random
import matplotlib.dates as mdates

# %%
tickers = ["AAPL","MSFT","GOOGL","META","AMZN","TSLA","NVDA"]

data = {}
for t in tickers:
    df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
    closes = df["Close"].astype(np.float32)
    mu, sigma = closes.mean(), closes.std()
    norm = (closes - mu) / sigma

    # Features and their windows are the exact same as the supervised learning 
    # EMA (5‑day)
    ema = closes.ewm(span=5, adjust=False).mean().astype(np.float32)

    # RSI (14‑day)
    delta = closes.diff()
    gain  = delta.clip(lower=0).rolling(14).mean()
    loss  = -delta.clip(upper=0).rolling(14).mean()
    rs    = gain / loss
    rsi   = (100 - 100/(1 + rs)).astype(np.float32)

    # MACD (12‑26)
    ema12 = closes.ewm(span=12, adjust=False).mean()
    ema26 = closes.ewm(span=26, adjust=False).mean()
    macd  = (ema12 - ema26).astype(np.float32)

    # Bollinger Bands (20‑day)
    mbb    = closes.rolling(20).mean()
    mbb_sd = closes.rolling(20).std()
    bb_upper = (mbb + 2*mbb_sd).astype(np.float32)
    bb_lower = (mbb - 2*mbb_sd).astype(np.float32)

    data[t] = {
        "dates":      df.index,
        "raw":        closes.values,
        "norm":       norm.values,
        "ema":        ema.values,
        "rsi":        rsi.values,
        "macd":       macd.values,
        "bb_upper":   bb_upper.values,
        "bb_lower":   bb_lower.values,
    }

raw_prices =    {t: data[t]["raw"]      for t in tickers}
normalized_prices = {t: data[t]["norm"]      for t in tickers}

# dropping any Nan values
for t in tickers:
    # stacking feature columns to detect any NaNs per row
    feat_stack = np.column_stack([
        data[t]["norm"],
        data[t]["ema"],
        data[t]["rsi"],
        data[t]["macd"],
        data[t]["bb_upper"],
        data[t]["bb_lower"],
    ])
    valid_rows = ~np.isnan(feat_stack).any(axis=1)
    start_idx = np.argmax(valid_rows)

    data[t]["dates"]    = data[t]["dates"][start_idx:]
    data[t]["raw"]      = data[t]["raw"][start_idx:]
    data[t]["norm"]     = data[t]["norm"][start_idx:]
    data[t]["ema"]      = data[t]["ema"][start_idx:]
    data[t]["rsi"]      = data[t]["rsi"][start_idx:]
    data[t]["macd"]     = data[t]["macd"][start_idx:]
    data[t]["bb_upper"] = data[t]["bb_upper"][start_idx:]
    data[t]["bb_lower"] = data[t]["bb_lower"][start_idx:]


for t in tickers:
    for feat in ["ema", "rsi", "macd", "bb_upper", "bb_lower"]:
        arr = data[t][feat]
        mu, sigma = arr.mean(), arr.std()
        # overwrite with z‑score normalization
        data[t][feat] = (arr - mu) / sigma
# Out:
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/2472174472.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start="2023-01-01", end="2025-01-01").copy()
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### PPO for multiple stocks

# %%
state_dim   = 5  # window size 
feat_dim    = 6   # number of features per timestep
action_dim  = 1   # how many features we have 
hidden_dim  = 64  # hidden layer size 
lr          = 1e-4
gamma       = 0.99
lam         = 0.95
clip_eps    = 0.2
epochs      = 200
batch_size  = 32
l2_lambda   = 1e-4

# build multi‐stock timeseries states with 6 features per timestep
state_window = state_dim
states, next_states, rewards, dones = [], [], [], []

num_days = len(data[tickers[0]]["norm"]) - state_window - 1  # safer to get length from data dict

for day in range(num_days):
    s_day, ns_day, r_day = [], [], []
    
    for t in tickers:
        features = np.column_stack([
            data[t]["norm"],
            data[t]["ema"],
            data[t]["rsi"],
            data[t]["macd"],
            data[t]["bb_upper"],
            data[t]["bb_lower"],
        ])
        
        s_feat = features[day:day+state_window]            # shape: (window, 6)
        ns_feat = features[day+1:day+1+state_window]        # shape: (window, 6)
        reward = (data[t]["norm"][day+state_window+1] - data[t]["norm"][day+state_window]).item()

        s_day.append(s_feat)
        ns_day.append(ns_feat)
        r_day.append(reward)
        
    states.append(s_day)
    next_states.append(ns_day)
    rewards.append(r_day)
    dones.append([0.0] * len(tickers))

# convert to tensors 
states      = torch.tensor(np.array(states),      dtype=torch.float32)
next_states = torch.tensor(np.array(next_states), dtype=torch.float32)
rewards     = torch.tensor(np.array(rewards),     dtype=torch.float32)
dones       = torch.tensor(np.array(dones),       dtype=torch.float32)

# Neural Network 
# initialising weights 
w1      = torch.nn.Parameter(torch.randn(state_dim * feat_dim, hidden_dim) * 0.1, requires_grad=True)
w2a     = torch.nn.Parameter(torch.randn(hidden_dim, action_dim) * 0.1, requires_grad=True)
w2c     = torch.nn.Parameter(torch.randn(hidden_dim, 1)          * 0.1, requires_grad=True)
log_std = torch.nn.Parameter(torch.zeros(action_dim))

# L2 & optimizer
optimizer = torch.optim.Adam([
    {'params': [w1, w2a, w2c], 'weight_decay': l2_lambda},
    {'params': [log_std],       'weight_decay': 0.0},], lr=lr)

# MLP forward
def mlp_forward(x, w1, w2):
    h = F.relu(x @ w1)
    return h @ w2

# Sample actions
# UPDATED: inputs w1, w2a, log_std so they can be accessed by the environment 
def get_action(state, w1, w2a, log_std):
    mean     = mlp_forward(state, w1, w2a)
    std      = log_std.exp()
    dist     = torch.distributions.Normal(mean, std)
    action   = dist.sample()
    log_prob = dist.log_prob(action).sum(axis=-1)
    return action, log_prob

actor_loss_hist = []
logprob_hist = []

# Collect trajectories (days × stocks) 
with torch.no_grad():
    all_actions   = []
    all_log_probs = []
    all_values    = []

    for day in range(len(states)):            # 1) loop over days
        for stock in range(states.size(1)):  # 2) inner loop over 5 stocks
            s = states[day, stock].view(1, -1)
            a, lp = get_action(s, w1, w2a, log_std)
            v     = mlp_forward(s, w1, w2c)

            all_actions  .append(a)
            all_log_probs.append(lp)
            all_values   .append(v)

    # bootstrap final values for each stock
    for stock in range(next_states.size(1)):
        s_final = next_states[-1, stock].view(1, -1)
        all_values.append(mlp_forward(s_final, w1, w2c))

# reshape into tensors
actions   = torch.cat(all_actions).view(len(states), -1, action_dim)
log_probs = torch.stack(all_log_probs).view(len(states), -1)
values    = torch.stack(all_values).view(len(states)+1, states.size(1))

# GAE calculation
advantages = torch.zeros_like(rewards)
for stock in range(states.size(1)):
    last_adv = 0
    for t in reversed(range(len(states))):
        delta    = rewards[t,stock] \
                   + gamma * values[t+1,stock] * (1 - dones[t,stock]) \
                   - values[t,stock]
        last_adv = delta + gamma * lam * (1 - dones[t,stock]) * last_adv
        advantages[t,stock] = last_adv
returns = advantages + values[:-1]

# flatten transitions for PPO
flat_states = states.view(-1, state_dim * feat_dim)
flat_actions = actions.view(-1, action_dim)
flat_lp_old  = log_probs.view(-1)
flat_ret     = returns.view(-1)
flat_adv     = advantages.view(-1)

critic_loss_hist = []
reward_hist = []
entropy_hist = []

# compute number of mini‑batches per epoch
n_trans   = flat_states.size(0)

n_batches = math.ceil(n_trans / batch_size)

# PPO training
for epoch in range(epochs):
    perm = torch.randperm(n_trans)
    epoch_actor_loss  = 0.0
    epoch_critic_loss = 0.0
    epoch_reward      = 0.0
    epoch_entropy     = 0.0
    epoch_logprob     = 0.0
    for batch_idx, start in enumerate(range(0, n_trans, batch_size), start=1):
        idx          = perm[start:start+batch_size]
        state_batch  = flat_states[idx]
        action_batch = flat_actions[idx].unsqueeze(1)
        old_logps_b  = flat_lp_old[idx].detach()
        return_batch = flat_ret[idx].detach()
        adv_batch    = flat_adv[idx].detach()

        # actor
        mean     = mlp_forward(state_batch, w1, w2a)
        std      = log_std.exp()
        dist     = torch.distributions.Normal(mean, std)
        new_lps  = dist.log_prob(action_batch).sum(axis=-1)

        ratio    = (new_lps - old_logps_b).exp()
        clipped  = torch.clamp(ratio, 1 - clip_eps, 1 + clip_eps) * adv_batch
        actor_loss = -torch.min(ratio * adv_batch, clipped).mean()

        # record entropy & log‐prob stats for this batch
        batch_entropy = dist.entropy().sum(axis=-1).mean()       # average entropy over batch
        batch_logprob = new_lps.mean()                          # average log‐prob over batch
        epoch_entropy += batch_entropy.item()
        epoch_logprob += batch_logprob.item()

        # critic
        value_pred  = mlp_forward(state_batch, w1, w2c).squeeze(-1)
        critic_loss = F.mse_loss(value_pred, return_batch)

        loss = actor_loss + 0.5 * critic_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_actor_loss  += actor_loss.item()
        epoch_critic_loss += critic_loss.item()
        epoch_reward      += return_batch.mean().item()

        # per‑batch print
        print(f"  Epoch {epoch+1}, Batch {batch_idx}/{n_batches} → Batch Loss: {loss.item():.4f}")

    actor_loss_hist .append(epoch_actor_loss  / n_batches)
    critic_loss_hist.append(epoch_critic_loss / n_batches)
    reward_hist     .append(epoch_reward      / n_batches)
    entropy_hist    .append(epoch_entropy     / n_batches)
    logprob_hist    .append(epoch_logprob     / n_batches)
# Out:
#   Epoch 1, Batch 1/105 → Batch Loss: -0.0498
#   Epoch 1, Batch 2/105 → Batch Loss: -0.0088
#   Epoch 1, Batch 3/105 → Batch Loss: -0.0528
#   Epoch 1, Batch 4/105 → Batch Loss: -0.1359
#   Epoch 1, Batch 5/105 → Batch Loss: -0.0702
#   Epoch 2, Batch 98/105 → Batch Loss: 0.0296
#   Epoch 2, Batch 99/105 → Batch Loss: -0.1095
#   Epoch 2, Batch 100/105 → Batch Loss: 0.2916
#   Epoch 2, Batch 101/105 → Batch Loss: 0.0181
#   Epoch 2, Batch 102/105 → Batch Loss: -0.0615
#   Epoch 2, Batch 103/105 → Batch Loss: -0.0648
#   Epoch 2, Batch 104/105 → Batch Loss: -0.0201
#   Epoch 2, Batch 105/105 → Batch Loss: -0.2018
#   Epoch 3, Batch 1/105 → Batch Loss: -0.1619
#   Epoch 3, Batch 2/105 → Batch Loss: 0.0873
#   Epoch 3, Batch 3/105 → Batch Loss: -0.0968
#   Epoch 3, Batch 4/105 → Batch Loss: -0.0189
#   Epoch 3, Batch 5/105 → Batch Loss: -0.1735
#   Epoch 3, Batch 6/105 → Batch Loss: -0.1519
#   Epoch 3, Batch 7/105 → Batch Loss: -0.0070
#   Epoch 3, Batch 8/105 → Batch Loss: -0.1195
#   Epoch 3, Batch 9/105 → Batch Loss: -0.0951
#   Epoch 3, Batch 10/105 → Batch Loss: -0.0526
#   Epoch 3, Batch 11/105 → Batch Loss: -0.1055
#   Epoch 3, Batch 12/105 → Batch Loss: 0.1119
#   Epoch 3, Batch 13/105 → Batch Loss: 0.0352
#   Epoch 3, Batch 14/105 → Batch Loss: 0.0571
#   Epoch 3, Batch 15/105 → Batch Loss: 0.0575
#   Epoch 3, Batch 16/105 → Batch Loss: 0.0569
#   Epoch 3, Batch 17/105 → Batch Loss: 0.0392
#   Epoch 3, Batch 18/105 → Batch Loss: 0.0241
#   Epoch 3, Batch 19/105 → Batch Loss: -0.0091
#   Epoch 3, Batch 20/105 → Batch Loss: 0.0452
#   Epoch 3, Batch 21/105 → Batch Loss: -0.0116
#   Epoch 3, Batch 22/105 → Batch Loss: 0.4326
#   Epoch 3, Batch 23/105 → Batch Loss: -0.0972
#   Epoch 3, Batch 24/105 → Batch Loss: -0.0378
#   Epoch 3, Batch 25/105 → Batch Loss: -0.1123
#   Epoch 3, Batch 26/105 → Batch Loss: -0.0231
#   Epoch 3, Batch 27/105 → Batch Loss: -0.0785
#   Epoch 3, Batch 28/105 → Batch Loss: 0.2674
#   Epoch 3, Batch 29/105 → Batch Loss: -0.1557
#   Epoch 3, Batch 30/105 → Batch Loss: -0.0199
#   Epoch 3, Batch 31/105 → Batch Loss: -0.0771
#   Epoch 3, Batch 32/105 → Batch Loss: 0.0894
#   Epoch 3, Batch 33/105 → Batch Loss: -0.0315
#   Epoch 3, Batch 34/105 → Batch Loss: -0.0267
#   Epoch 3, Batch 35/105 → Batch Loss: -0.1261
#   Epoch 3, Batch 36/105 → Batch Loss: -0.0517
#   Epoch 3, Batch 37/105 → Batch Loss: -0.0146
#   Epoch 3, Batch 38/105 → Batch Loss: -0.0423
#   Epoch 3, Batch 39/105 → Batch Loss: -0.0192
#   Epoch 3, Batch 40/105 → Batch Loss: -0.0172
#   Epoch 3, Batch 41/105 → Batch Loss: 0.0113
#   Epoch 3, Batch 42/105 → Batch Loss: -0.0874
#   Epoch 3, Batch 43/105 → Batch Loss: -0.0186
#   Epoch 3, Batch 44/105 → Batch Loss: -0.0563
#   Epoch 3, Batch 45/105 → Batch Loss: -0.0562
#   Epoch 3, Batch 46/105 → Batch Loss: -0.0710
#   Epoch 3, Batch 47/105 → Batch Loss: 0.0395
#   Epoch 3, Batch 48/105 → Batch Loss: -0.1480
#   Epoch 3, Batch 49/105 → Batch Loss: 0.0088
#   Epoch 3, Batch 50/105 → Batch Loss: 0.0414
#   Epoch 3, Batch 51/105 → Batch Loss: -0.0572
#   Epoch 3, Batch 52/105 → Batch Loss: 0.0359
#   Epoch 3, Batch 53/105 → Batch Loss: -0.0744
#   Epoch 3, Batch 54/105 → Batch Loss: 0.2964
#   Epoch 3, Batch 55/105 → Batch Loss: -0.0034
#   Epoch 3, Batch 56/105 → Batch Loss: -0.0143
#   Epoch 3, Batch 57/105 → Batch Loss: 0.2913
#   Epoch 3, Batch 58/105 → Batch Loss: -0.1366
#   Epoch 3, Batch 59/105 → Batch Loss: 0.4614
#   Epoch 3, Batch 60/105 → Batch Loss: -0.1258
#   Epoch 3, Batch 61/105 → Batch Loss: -0.1232
#   Epoch 3, Batch 62/105 → Batch Loss: 0.0684
#   Epoch 3, Batch 63/105 → Batch Loss: -0.1027
#   Epoch 3, Batch 64/105 → Batch Loss: 0.1360
#   Epoch 3, Batch 65/105 → Batch Loss: -0.0128
#   Epoch 3, Batch 66/105 → Batch Loss: 0.0545
#   Epoch 3, Batch 67/105 → Batch Loss: 0.0191
#   Epoch 3, Batch 68/105 → Batch Loss: -0.0954
#   Epoch 3, Batch 69/105 → Batch Loss: 0.0561
#   Epoch 3, Batch 70/105 → Batch Loss: 0.0818
#   Epoch 3, Batch 71/105 → Batch Loss: -0.0086
#   Epoch 3, Batch 72/105 → Batch Loss: -0.0712
#   Epoch 3, Batch 73/105 → Batch Loss: 0.0335
#   Epoch 3, Batch 74/105 → Batch Loss: -0.0633
#   Epoch 3, Batch 75/105 → Batch Loss: 0.0590
#   Epoch 3, Batch 76/105 → Batch Loss: -0.0730
#   Epoch 3, Batch 77/105 → Batch Loss: -0.0515
#   Epoch 3, Batch 78/105 → Batch Loss: -0.0573
#   Epoch 3, Batch 79/105 → Batch Loss: 0.2378
#   Epoch 3, Batch 80/105 → Batch Loss: -0.1461
#   Epoch 3, Batch 81/105 → Batch Loss: -0.1493
#   Epoch 3, Batch 82/105 → Batch Loss: 0.0252
#   Epoch 3, Batch 83/105 → Batch Loss: -0.0237
#   Epoch 3, Batch 84/105 → Batch Loss: -0.0273
#   Epoch 3, Batch 85/105 → Batch Loss: -0.0164
#   Epoch 3, Batch 86/105 → Batch Loss: -0.1190
#   Epoch 3, Batch 87/105 → Batch Loss: 0.0215
#   Epoch 3, Batch 88/105 → Batch Loss: 0.0730
#   Epoch 3, Batch 89/105 → Batch Loss: -0.0584
#   Epoch 3, Batch 90/105 → Batch Loss: 1.2686
#   Epoch 5, Batch 79/105 → Batch Loss: -0.1349
#   Epoch 5, Batch 80/105 → Batch Loss: -0.1801
#   Epoch 5, Batch 81/105 → Batch Loss: -0.1476
#   Epoch 5, Batch 82/105 → Batch Loss: -0.1278
#   Epoch 5, Batch 83/105 → Batch Loss: 0.2963
#   Epoch 5, Batch 84/105 → Batch Loss: -0.0703
#   Epoch 5, Batch 85/105 → Batch Loss: -0.0400
#   Epoch 5, Batch 86/105 → Batch Loss: -0.0367
#   Epoch 5, Batch 87/105 → Batch Loss: 0.0456
#   Epoch 5, Batch 88/105 → Batch Loss: 0.0638
#   Epoch 5, Batch 89/105 → Batch Loss: 0.0655
#   Epoch 5, Batch 90/105 → Batch Loss: -0.0265
#   Epoch 5, Batch 91/105 → Batch Loss: -0.0682
#   Epoch 5, Batch 92/105 → Batch Loss: -0.0771
#   Epoch 5, Batch 93/105 → Batch Loss: -0.1754
#   Epoch 5, Batch 94/105 → Batch Loss: -0.1430
#   Epoch 5, Batch 95/105 → Batch Loss: 0.0393
#   Epoch 5, Batch 96/105 → Batch Loss: -0.0906
#   Epoch 5, Batch 97/105 → Batch Loss: -0.0628
#   Epoch 5, Batch 98/105 → Batch Loss: -0.0928
#   Epoch 5, Batch 99/105 → Batch Loss: -0.0633
#   Epoch 5, Batch 100/105 → Batch Loss: -0.0464
#   Epoch 5, Batch 101/105 → Batch Loss: -0.0238
#   Epoch 5, Batch 102/105 → Batch Loss: -0.0167
#   Epoch 5, Batch 103/105 → Batch Loss: -0.0986
#   Epoch 5, Batch 104/105 → Batch Loss: 0.1075
#   Epoch 5, Batch 105/105 → Batch Loss: -0.0560
#   Epoch 6, Batch 1/105 → Batch Loss: -0.0575
#   Epoch 6, Batch 2/105 → Batch Loss: -0.1502
#   Epoch 6, Batch 3/105 → Batch Loss: -0.1530
#   Epoch 6, Batch 4/105 → Batch Loss: -0.0692
#   Epoch 6, Batch 5/105 → Batch Loss: 0.0074
#   Epoch 6, Batch 6/105 → Batch Loss: -0.0705
#   Epoch 6, Batch 7/105 → Batch Loss: -0.1125
#   Epoch 6, Batch 8/105 → Batch Loss: -0.0581
#   Epoch 6, Batch 9/105 → Batch Loss: -0.0601
#   Epoch 6, Batch 10/105 → Batch Loss: -0.0558
#   Epoch 6, Batch 11/105 → Batch Loss: 0.0045
#   Epoch 6, Batch 12/105 → Batch Loss: -0.0184
#   Epoch 6, Batch 13/105 → Batch Loss: -0.0683
#   Epoch 6, Batch 14/105 → Batch Loss: -0.0921
#   Epoch 6, Batch 15/105 → Batch Loss: -0.1563
#   Epoch 6, Batch 16/105 → Batch Loss: -0.0201
#   Epoch 6, Batch 17/105 → Batch Loss: 0.0156
#   Epoch 6, Batch 18/105 → Batch Loss: 0.0457
#   Epoch 6, Batch 19/105 → Batch Loss: -0.0430
#   Epoch 6, Batch 20/105 → Batch Loss: 0.1287
#   Epoch 6, Batch 21/105 → Batch Loss: 0.1135
#   Epoch 6, Batch 22/105 → Batch Loss: -0.1507
#   Epoch 6, Batch 23/105 → Batch Loss: 0.0580
#   Epoch 6, Batch 24/105 → Batch Loss: -0.0169
#   Epoch 6, Batch 25/105 → Batch Loss: -0.0065
#   Epoch 6, Batch 26/105 → Batch Loss: -0.0998
#   Epoch 6, Batch 27/105 → Batch Loss: 0.0553
#   Epoch 6, Batch 28/105 → Batch Loss: 0.0423
#   Epoch 6, Batch 29/105 → Batch Loss: -0.0934
#   Epoch 6, Batch 30/105 → Batch Loss: -0.0838
#   Epoch 6, Batch 31/105 → Batch Loss: -0.0702
#   Epoch 6, Batch 32/105 → Batch Loss: -0.0408
#   Epoch 6, Batch 33/105 → Batch Loss: -0.0167
#   Epoch 6, Batch 34/105 → Batch Loss: -0.0662
#   Epoch 6, Batch 35/105 → Batch Loss: -0.0581
#   Epoch 6, Batch 36/105 → Batch Loss: -0.1093
#   Epoch 6, Batch 37/105 → Batch Loss: -0.0551
#   Epoch 6, Batch 38/105 → Batch Loss: -0.0131
#   Epoch 6, Batch 39/105 → Batch Loss: -0.0466
#   Epoch 6, Batch 40/105 → Batch Loss: 0.0005
#   Epoch 6, Batch 41/105 → Batch Loss: -0.0067
#   Epoch 6, Batch 42/105 → Batch Loss: -0.0559
#   Epoch 6, Batch 43/105 → Batch Loss: -0.0335
#   Epoch 6, Batch 44/105 → Batch Loss: -0.0493
#   Epoch 6, Batch 45/105 → Batch Loss: 0.1872
#   Epoch 6, Batch 46/105 → Batch Loss: -0.1001
#   Epoch 6, Batch 47/105 → Batch Loss: -0.1163
#   Epoch 6, Batch 48/105 → Batch Loss: -0.0799
#   Epoch 6, Batch 49/105 → Batch Loss: -0.1057
#   Epoch 6, Batch 50/105 → Batch Loss: -0.0702
#   Epoch 6, Batch 51/105 → Batch Loss: -0.0617
#   Epoch 6, Batch 52/105 → Batch Loss: 0.0089
#   Epoch 6, Batch 53/105 → Batch Loss: -0.0151
#   Epoch 6, Batch 54/105 → Batch Loss: -0.0314
#   Epoch 6, Batch 55/105 → Batch Loss: -0.0934
#   Epoch 6, Batch 56/105 → Batch Loss: -0.0855
#   Epoch 6, Batch 57/105 → Batch Loss: -0.0749
#   Epoch 6, Batch 58/105 → Batch Loss: -0.0929
#   Epoch 6, Batch 59/105 → Batch Loss: -0.0040
#   Epoch 6, Batch 60/105 → Batch Loss: 0.3001
#   Epoch 6, Batch 61/105 → Batch Loss: -0.0664
#   Epoch 6, Batch 62/105 → Batch Loss: -0.0541
#   Epoch 6, Batch 63/105 → Batch Loss: -0.1693
#   Epoch 6, Batch 64/105 → Batch Loss: 0.1016
#   Epoch 6, Batch 65/105 → Batch Loss: -0.1467
#   Epoch 6, Batch 66/105 → Batch Loss: 0.1570
#   Epoch 6, Batch 67/105 → Batch Loss: -0.1486
#   Epoch 6, Batch 68/105 → Batch Loss: -0.1323
#   Epoch 6, Batch 69/105 → Batch Loss: -0.0223
#   Epoch 6, Batch 70/105 → Batch Loss: 0.0312
#   Epoch 6, Batch 71/105 → Batch Loss: 0.1996
#   Epoch 6, Batch 72/105 → Batch Loss: -0.0567
#   Epoch 6, Batch 73/105 → Batch Loss: -0.0555
#   Epoch 6, Batch 74/105 → Batch Loss: -0.0863
#   Epoch 6, Batch 75/105 → Batch Loss: -0.1082
#   Epoch 6, Batch 76/105 → Batch Loss: 0.1466
#   Epoch 6, Batch 77/105 → Batch Loss: -0.0925
#   Epoch 6, Batch 78/105 → Batch Loss: -0.0190
#   Epoch 6, Batch 79/105 → Batch Loss: -0.0292
#   Epoch 6, Batch 80/105 → Batch Loss: -0.0260
#   Epoch 6, Batch 81/105 → Batch Loss: -0.1509
#   Epoch 6, Batch 82/105 → Batch Loss: -0.0982
#   Epoch 6, Batch 83/105 → Batch Loss: 0.4373
#   Epoch 6, Batch 84/105 → Batch Loss: 0.0973
#   Epoch 6, Batch 85/105 → Batch Loss: 0.0801
#   Epoch 6, Batch 86/105 → Batch Loss: 0.1258
#   Epoch 6, Batch 87/105 → Batch Loss: -0.0185
#   Epoch 6, Batch 88/105 → Batch Loss: -0.0011
#   Epoch 6, Batch 89/105 → Batch Loss: 0.1155
#   Epoch 6, Batch 90/105 → Batch Loss: -0.0197
#   Epoch 6, Batch 91/105 → Batch Loss: -0.0858
#   Epoch 6, Batch 92/105 → Batch Loss: 0.0522
#   Epoch 6, Batch 93/105 → Batch Loss: -0.0792
#   Epoch 6, Batch 94/105 → Batch Loss: -0.0233
#   Epoch 6, Batch 95/105 → Batch Loss: -0.0660
#   Epoch 6, Batch 96/105 → Batch Loss: 0.0489
#   Epoch 6, Batch 97/105 → Batch Loss: 0.0314
#   Epoch 6, Batch 98/105 → Batch Loss: 0.0464
#   Epoch 6, Batch 99/105 → Batch Loss: -0.0170
#   Epoch 6, Batch 100/105 → Batch Loss: -0.0321
#   Epoch 6, Batch 101/105 → Batch Loss: 0.6090
#   Epoch 6, Batch 102/105 → Batch Loss: 0.7514
#   Epoch 6, Batch 103/105 → Batch Loss: 0.0344
#   Epoch 6, Batch 104/105 → Batch Loss: -0.0625
#   Epoch 6, Batch 105/105 → Batch Loss: 0.1580
#   Epoch 7, Batch 1/105 → Batch Loss: -0.1207
#   Epoch 7, Batch 2/105 → Batch Loss: -0.0432
#   Epoch 7, Batch 3/105 → Batch Loss: 0.0989
#   Epoch 7, Batch 4/105 → Batch Loss: 0.1086
#   Epoch 7, Batch 5/105 → Batch Loss: -0.1496
#   Epoch 7, Batch 6/105 → Batch Loss: -0.0107
#   Epoch 7, Batch 7/105 → Batch Loss: -0.0210
#   Epoch 7, Batch 8/105 → Batch Loss: -0.0480
#   Epoch 7, Batch 9/105 → Batch Loss: -0.0119
#   Epoch 7, Batch 10/105 → Batch Loss: 0.0056
#   Epoch 7, Batch 11/105 → Batch Loss: -0.0640
#   Epoch 7, Batch 12/105 → Batch Loss: -0.0936
#   Epoch 7, Batch 13/105 → Batch Loss: -0.0719
#   Epoch 7, Batch 14/105 → Batch Loss: -0.1393
#   Epoch 7, Batch 15/105 → Batch Loss: 0.2740
#   Epoch 9, Batch 102/105 → Batch Loss: -0.1234
#   Epoch 9, Batch 103/105 → Batch Loss: -0.0519
#   Epoch 9, Batch 104/105 → Batch Loss: -0.0170
#   Epoch 9, Batch 105/105 → Batch Loss: 0.2207
#   Epoch 10, Batch 1/105 → Batch Loss: 0.0125
#   Epoch 10, Batch 2/105 → Batch Loss: -0.0275
#   Epoch 10, Batch 3/105 → Batch Loss: -0.0024
#   Epoch 10, Batch 4/105 → Batch Loss: -0.0106
#   Epoch 10, Batch 5/105 → Batch Loss: 0.0561
#   Epoch 10, Batch 6/105 → Batch Loss: -0.0533
#   Epoch 10, Batch 7/105 → Batch Loss: -0.1092
#   Epoch 10, Batch 8/105 → Batch Loss: 0.1030
#   Epoch 10, Batch 9/105 → Batch Loss: -0.0376
#   Epoch 10, Batch 10/105 → Batch Loss: -0.0877
#   Epoch 10, Batch 11/105 → Batch Loss: -0.0526
#   Epoch 10, Batch 12/105 → Batch Loss: -0.1775
#   Epoch 10, Batch 13/105 → Batch Loss: 0.0497
#   Epoch 10, Batch 14/105 → Batch Loss: -0.0762
#   Epoch 10, Batch 15/105 → Batch Loss: 0.0484
#   Epoch 10, Batch 16/105 → Batch Loss: -0.0106
#   Epoch 10, Batch 17/105 → Batch Loss: -0.0200
#   Epoch 10, Batch 18/105 → Batch Loss: 0.2822
#   Epoch 10, Batch 19/105 → Batch Loss: -0.0221
#   Epoch 10, Batch 20/105 → Batch Loss: -0.0825
#   Epoch 10, Batch 21/105 → Batch Loss: -0.0143
#   Epoch 10, Batch 22/105 → Batch Loss: -0.1004
#   Epoch 10, Batch 23/105 → Batch Loss: -0.0504
#   Epoch 10, Batch 24/105 → Batch Loss: 0.0464
#   Epoch 10, Batch 25/105 → Batch Loss: -0.0742
#   Epoch 10, Batch 26/105 → Batch Loss: 0.1179
#   Epoch 10, Batch 27/105 → Batch Loss: -0.0316
#   Epoch 10, Batch 28/105 → Batch Loss: -0.0612
#   Epoch 10, Batch 29/105 → Batch Loss: 0.2701
#   Epoch 10, Batch 30/105 → Batch Loss: 0.0110
#   Epoch 10, Batch 31/105 → Batch Loss: -0.0803
#   Epoch 10, Batch 32/105 → Batch Loss: -0.1085
#   Epoch 10, Batch 33/105 → Batch Loss: -0.0118
#   Epoch 10, Batch 34/105 → Batch Loss: -0.0497
#   Epoch 10, Batch 35/105 → Batch Loss: -0.0320
#   Epoch 10, Batch 36/105 → Batch Loss: -0.0384
#   Epoch 10, Batch 37/105 → Batch Loss: -0.0623
#   Epoch 10, Batch 38/105 → Batch Loss: 0.0661
#   Epoch 10, Batch 39/105 → Batch Loss: -0.0878
#   Epoch 10, Batch 40/105 → Batch Loss: 0.5374
#   Epoch 10, Batch 41/105 → Batch Loss: -0.0049
#   Epoch 10, Batch 42/105 → Batch Loss: -0.0093
#   Epoch 10, Batch 43/105 → Batch Loss: 0.0748
#   Epoch 10, Batch 44/105 → Batch Loss: -0.0218
#   Epoch 10, Batch 45/105 → Batch Loss: 0.0272
#   Epoch 10, Batch 46/105 → Batch Loss: -0.1248
#   Epoch 10, Batch 47/105 → Batch Loss: -0.0736
#   Epoch 10, Batch 48/105 → Batch Loss: -0.0110
#   Epoch 10, Batch 49/105 → Batch Loss: -0.0695
#   Epoch 10, Batch 50/105 → Batch Loss: -0.0737
#   Epoch 10, Batch 51/105 → Batch Loss: -0.0940
#   Epoch 10, Batch 52/105 → Batch Loss: -0.0416
#   Epoch 10, Batch 53/105 → Batch Loss: 0.0243
#   Epoch 10, Batch 54/105 → Batch Loss: 0.0653
#   Epoch 10, Batch 55/105 → Batch Loss: -0.0585
#   Epoch 10, Batch 56/105 → Batch Loss: -0.0755
#   Epoch 10, Batch 57/105 → Batch Loss: -0.0155
#   Epoch 10, Batch 58/105 → Batch Loss: 0.0400
#   Epoch 10, Batch 59/105 → Batch Loss: -0.1045
#   Epoch 10, Batch 60/105 → Batch Loss: -0.0029
#   Epoch 10, Batch 61/105 → Batch Loss: -0.0123
#   Epoch 10, Batch 62/105 → Batch Loss: -0.0249
#   Epoch 10, Batch 63/105 → Batch Loss: 0.0747
#   Epoch 10, Batch 64/105 → Batch Loss: -0.0060
#   Epoch 10, Batch 65/105 → Batch Loss: -0.0025
#   Epoch 10, Batch 66/105 → Batch Loss: -0.0570
#   Epoch 10, Batch 67/105 → Batch Loss: -0.1460
#   Epoch 10, Batch 68/105 → Batch Loss: -0.0629
#   Epoch 10, Batch 69/105 → Batch Loss: 0.0041
#   Epoch 10, Batch 70/105 → Batch Loss: -0.1453
#   Epoch 10, Batch 71/105 → Batch Loss: -0.0101
#   Epoch 10, Batch 72/105 → Batch Loss: 0.0070
#   Epoch 10, Batch 73/105 → Batch Loss: -0.0437
#   Epoch 10, Batch 74/105 → Batch Loss: 0.0173
#   Epoch 10, Batch 75/105 → Batch Loss: 0.3426
#   Epoch 10, Batch 76/105 → Batch Loss: 0.0608
#   Epoch 10, Batch 77/105 → Batch Loss: -0.0781
#   Epoch 10, Batch 78/105 → Batch Loss: -0.1357
#   Epoch 10, Batch 79/105 → Batch Loss: -0.0975
#   Epoch 10, Batch 80/105 → Batch Loss: -0.1095
#   Epoch 10, Batch 81/105 → Batch Loss: -0.0953
#   Epoch 10, Batch 82/105 → Batch Loss: 0.3215
#   Epoch 10, Batch 83/105 → Batch Loss: -0.0720
#   Epoch 10, Batch 84/105 → Batch Loss: -0.1447
#   Epoch 10, Batch 85/105 → Batch Loss: -0.1332
#   Epoch 10, Batch 86/105 → Batch Loss: 0.0859
#   Epoch 10, Batch 87/105 → Batch Loss: -0.0536
#   Epoch 10, Batch 88/105 → Batch Loss: -0.1225
#   Epoch 10, Batch 89/105 → Batch Loss: -0.0355
#   Epoch 10, Batch 90/105 → Batch Loss: -0.1270
#   Epoch 10, Batch 91/105 → Batch Loss: -0.0815
#   Epoch 10, Batch 92/105 → Batch Loss: 0.0122
#   Epoch 10, Batch 93/105 → Batch Loss: 0.0567
#   Epoch 10, Batch 94/105 → Batch Loss: -0.1809
#   Epoch 10, Batch 95/105 → Batch Loss: -0.1084
#   Epoch 10, Batch 96/105 → Batch Loss: -0.0523
#   Epoch 10, Batch 97/105 → Batch Loss: -0.0449
#   Epoch 10, Batch 98/105 → Batch Loss: -0.1664
#   Epoch 10, Batch 99/105 → Batch Loss: -0.0577
#   Epoch 10, Batch 100/105 → Batch Loss: 0.0739
#   Epoch 10, Batch 101/105 → Batch Loss: -0.0005
#   Epoch 10, Batch 102/105 → Batch Loss: -0.1022
#   Epoch 10, Batch 103/105 → Batch Loss: -0.0919
#   Epoch 10, Batch 104/105 → Batch Loss: -0.0483
# ...
#   Epoch 197, Batch 87/105 → Batch Loss: -0.0714
#   Epoch 197, Batch 88/105 → Batch Loss: -0.1113
#   Epoch 197, Batch 89/105 → Batch Loss: -0.0417
#   Epoch 197, Batch 90/105 → Batch Loss: -0.0197
#   Epoch 197, Batch 91/105 → Batch Loss: -0.0569
#   Epoch 197, Batch 92/105 → Batch Loss: -0.0489
#   Epoch 197, Batch 93/105 → Batch Loss: -0.0062
#   Epoch 197, Batch 94/105 → Batch Loss: 0.0023
#   Epoch 197, Batch 95/105 → Batch Loss: -0.0132
#   Epoch 197, Batch 96/105 → Batch Loss: -0.0462
#   Epoch 197, Batch 97/105 → Batch Loss: -0.1592
#   Epoch 197, Batch 98/105 → Batch Loss: -0.1017
#   Epoch 197, Batch 99/105 → Batch Loss: -0.1463
#   Epoch 197, Batch 100/105 → Batch Loss: -0.0815
#   Epoch 197, Batch 101/105 → Batch Loss: -0.0944
#   Epoch 197, Batch 102/105 → Batch Loss: 0.0182
#   Epoch 197, Batch 103/105 → Batch Loss: -0.0535
#   Epoch 197, Batch 104/105 → Batch Loss: -0.1463
#   Epoch 197, Batch 105/105 → Batch Loss: 0.0178
#   Epoch 198, Batch 1/105 → Batch Loss: 0.0125
#   Epoch 198, Batch 2/105 → Batch Loss: -0.0315
#   Epoch 198, Batch 3/105 → Batch Loss: -0.0122
#   Epoch 198, Batch 4/105 → Batch Loss: -0.0015
#   Epoch 198, Batch 5/105 → Batch Loss: -0.0426
#   Epoch 198, Batch 6/105 → Batch Loss: -0.0227
#   Epoch 198, Batch 7/105 → Batch Loss: -0.0176
#   Epoch 198, Batch 8/105 → Batch Loss: -0.0973
#   Epoch 198, Batch 9/105 → Batch Loss: -0.1403
#   Epoch 198, Batch 10/105 → Batch Loss: -0.0285
#   Epoch 198, Batch 11/105 → Batch Loss: 0.0611
#   Epoch 198, Batch 12/105 → Batch Loss: -0.1003
#   Epoch 198, Batch 13/105 → Batch Loss: 0.1805
#   Epoch 198, Batch 14/105 → Batch Loss: 0.0244
#   Epoch 198, Batch 15/105 → Batch Loss: -0.0913
#   Epoch 198, Batch 16/105 → Batch Loss: 0.0144
#   Epoch 198, Batch 17/105 → Batch Loss: -0.1394
#   Epoch 198, Batch 18/105 → Batch Loss: -0.0274
#   Epoch 198, Batch 19/105 → Batch Loss: -0.1478
#   Epoch 198, Batch 20/105 → Batch Loss: -0.1422
#   Epoch 198, Batch 21/105 → Batch Loss: -0.1013
#   Epoch 198, Batch 22/105 → Batch Loss: -0.0720
#   Epoch 198, Batch 23/105 → Batch Loss: -0.0570
#   Epoch 198, Batch 24/105 → Batch Loss: 0.0119
#   Epoch 198, Batch 25/105 → Batch Loss: 0.0136
#   Epoch 198, Batch 26/105 → Batch Loss: 0.0600
#   Epoch 198, Batch 27/105 → Batch Loss: -0.0750
#   Epoch 198, Batch 28/105 → Batch Loss: -0.0240
#   Epoch 198, Batch 29/105 → Batch Loss: -0.0414
#   Epoch 198, Batch 30/105 → Batch Loss: 0.3464
#   Epoch 198, Batch 31/105 → Batch Loss: 0.0334
#   Epoch 198, Batch 32/105 → Batch Loss: -0.0633
#   Epoch 198, Batch 33/105 → Batch Loss: -0.1402
#   Epoch 198, Batch 34/105 → Batch Loss: -0.0326
#   Epoch 198, Batch 35/105 → Batch Loss: -0.1353
#   Epoch 198, Batch 36/105 → Batch Loss: -0.1032
#   Epoch 198, Batch 37/105 → Batch Loss: -0.0248
#   Epoch 198, Batch 38/105 → Batch Loss: -0.1397
#   Epoch 198, Batch 39/105 → Batch Loss: -0.0787
#   Epoch 198, Batch 40/105 → Batch Loss: -0.0810
#   Epoch 198, Batch 41/105 → Batch Loss: -0.1069
#   Epoch 198, Batch 42/105 → Batch Loss: -0.1397
#   Epoch 198, Batch 43/105 → Batch Loss: -0.0052
#   Epoch 198, Batch 44/105 → Batch Loss: -0.0692
#   Epoch 198, Batch 45/105 → Batch Loss: -0.0517
#   Epoch 198, Batch 46/105 → Batch Loss: -0.0715
#   Epoch 198, Batch 47/105 → Batch Loss: -0.0286
#   Epoch 198, Batch 48/105 → Batch Loss: -0.0455
#   Epoch 198, Batch 49/105 → Batch Loss: -0.0423
#   Epoch 198, Batch 50/105 → Batch Loss: 0.1223
#   Epoch 198, Batch 51/105 → Batch Loss: -0.0186
#   Epoch 198, Batch 52/105 → Batch Loss: -0.0500
#   Epoch 198, Batch 53/105 → Batch Loss: 0.0713
#   Epoch 198, Batch 54/105 → Batch Loss: -0.1653
#   Epoch 198, Batch 55/105 → Batch Loss: -0.0830
#   Epoch 198, Batch 56/105 → Batch Loss: -0.0271
#   Epoch 198, Batch 57/105 → Batch Loss: -0.0975
#   Epoch 198, Batch 58/105 → Batch Loss: -0.1251
#   Epoch 198, Batch 59/105 → Batch Loss: 0.0170
#   Epoch 198, Batch 60/105 → Batch Loss: -0.0433
#   Epoch 198, Batch 61/105 → Batch Loss: -0.0783
#   Epoch 198, Batch 62/105 → Batch Loss: 0.0394
#   Epoch 198, Batch 63/105 → Batch Loss: -0.0159
#   Epoch 198, Batch 64/105 → Batch Loss: -0.0076
#   Epoch 198, Batch 65/105 → Batch Loss: -0.1160
#   Epoch 198, Batch 66/105 → Batch Loss: -0.1308
#   Epoch 198, Batch 67/105 → Batch Loss: -0.1345
#   Epoch 198, Batch 68/105 → Batch Loss: -0.1370
#   Epoch 198, Batch 69/105 → Batch Loss: -0.0594
#   Epoch 198, Batch 70/105 → Batch Loss: -0.0345
#   Epoch 198, Batch 71/105 → Batch Loss: -0.1033
#   Epoch 198, Batch 72/105 → Batch Loss: -0.0408
#   Epoch 198, Batch 73/105 → Batch Loss: -0.0880
#   Epoch 198, Batch 74/105 → Batch Loss: -0.0695
#   Epoch 198, Batch 75/105 → Batch Loss: 0.0126
#   Epoch 198, Batch 76/105 → Batch Loss: -0.0222
#   Epoch 198, Batch 77/105 → Batch Loss: 0.0096
#   Epoch 198, Batch 78/105 → Batch Loss: 0.0020
#   Epoch 198, Batch 79/105 → Batch Loss: -0.0930
#   Epoch 198, Batch 80/105 → Batch Loss: -0.0399
#   Epoch 198, Batch 81/105 → Batch Loss: -0.0701
#   Epoch 198, Batch 82/105 → Batch Loss: -0.0432
#   Epoch 198, Batch 83/105 → Batch Loss: -0.0913
#   Epoch 198, Batch 84/105 → Batch Loss: -0.0334
#   Epoch 198, Batch 85/105 → Batch Loss: -0.0588
#   Epoch 198, Batch 86/105 → Batch Loss: -0.1050
#   Epoch 198, Batch 87/105 → Batch Loss: 0.0205
#   Epoch 198, Batch 88/105 → Batch Loss: -0.0126
#   Epoch 198, Batch 89/105 → Batch Loss: -0.0608
#   Epoch 198, Batch 90/105 → Batch Loss: -0.0917
#   Epoch 198, Batch 91/105 → Batch Loss: 0.0036
#   Epoch 198, Batch 92/105 → Batch Loss: -0.0877
#   Epoch 198, Batch 93/105 → Batch Loss: -0.0300
#   Epoch 198, Batch 94/105 → Batch Loss: -0.0860
#   Epoch 198, Batch 95/105 → Batch Loss: -0.0962
#   Epoch 198, Batch 96/105 → Batch Loss: -0.0243
#   Epoch 198, Batch 97/105 → Batch Loss: -0.0156
#   Epoch 198, Batch 98/105 → Batch Loss: -0.0414
#   Epoch 198, Batch 99/105 → Batch Loss: 0.0112
#   Epoch 198, Batch 100/105 → Batch Loss: 0.0474
#   Epoch 198, Batch 101/105 → Batch Loss: 0.0248
#   Epoch 198, Batch 102/105 → Batch Loss: -0.1043
#   Epoch 198, Batch 103/105 → Batch Loss: -0.1111
#   Epoch 198, Batch 104/105 → Batch Loss: -0.0352
#   Epoch 198, Batch 105/105 → Batch Loss: -0.0487
#   Epoch 199, Batch 1/105 → Batch Loss: -0.0703
#   Epoch 199, Batch 2/105 → Batch Loss: 0.0103
#   Epoch 199, Batch 3/105 → Batch Loss: -0.1116
#   Epoch 199, Batch 4/105 → Batch Loss: -0.0667
#   Epoch 199, Batch 5/105 → Batch Loss: 0.0222
#   Epoch 199, Batch 6/105 → Batch Loss: -0.0974
#   Epoch 199, Batch 7/105 → Batch Loss: -0.0366
#   Epoch 199, Batch 8/105 → Batch Loss: -0.1421
#   Epoch 199, Batch 9/105 → Batch Loss: -0.0124
#   Epoch 199, Batch 10/105 → Batch Loss: -0.0148
#   Epoch 199, Batch 11/105 → Batch Loss: -0.0879
#   Epoch 199, Batch 12/105 → Batch Loss: -0.0080
#   Epoch 199, Batch 13/105 → Batch Loss: -0.0626
#   Epoch 199, Batch 14/105 → Batch Loss: -0.1304
#   Epoch 199, Batch 15/105 → Batch Loss: -0.0401
#   Epoch 199, Batch 16/105 → Batch Loss: 0.0282
#   Epoch 199, Batch 17/105 → Batch Loss: -0.0746
#   Epoch 199, Batch 18/105 → Batch Loss: -0.0466
#   Epoch 199, Batch 19/105 → Batch Loss: 0.1048
#   Epoch 199, Batch 20/105 → Batch Loss: -0.0227
#   Epoch 199, Batch 21/105 → Batch Loss: -0.1410
#   Epoch 199, Batch 22/105 → Batch Loss: 0.0340
#   Epoch 199, Batch 23/105 → Batch Loss: -0.0129
#   Epoch 199, Batch 24/105 → Batch Loss: 0.1130
#   Epoch 199, Batch 25/105 → Batch Loss: -0.0725
#   Epoch 199, Batch 26/105 → Batch Loss: 0.0591
#   Epoch 199, Batch 27/105 → Batch Loss: -0.0387
#   Epoch 199, Batch 28/105 → Batch Loss: -0.0003
#   Epoch 199, Batch 29/105 → Batch Loss: -0.0125
#   Epoch 199, Batch 30/105 → Batch Loss: -0.1165
#   Epoch 199, Batch 31/105 → Batch Loss: -0.0707
#   Epoch 199, Batch 32/105 → Batch Loss: -0.0210
#   Epoch 199, Batch 33/105 → Batch Loss: 0.0357
#   Epoch 199, Batch 34/105 → Batch Loss: -0.0254
#   Epoch 199, Batch 35/105 → Batch Loss: -0.1583
#   Epoch 199, Batch 36/105 → Batch Loss: -0.0773
#   Epoch 199, Batch 37/105 → Batch Loss: 0.0261
#   Epoch 199, Batch 38/105 → Batch Loss: -0.0392
#   Epoch 199, Batch 39/105 → Batch Loss: -0.0562
#   Epoch 199, Batch 40/105 → Batch Loss: -0.1039
#   Epoch 199, Batch 41/105 → Batch Loss: -0.0862
#   Epoch 199, Batch 42/105 → Batch Loss: -0.1408
#   Epoch 199, Batch 43/105 → Batch Loss: -0.0872
#   Epoch 199, Batch 44/105 → Batch Loss: -0.0893
#   Epoch 199, Batch 45/105 → Batch Loss: -0.0619
#   Epoch 199, Batch 46/105 → Batch Loss: -0.0898
#   Epoch 199, Batch 47/105 → Batch Loss: 0.0236
#   Epoch 199, Batch 48/105 → Batch Loss: -0.0749
#   Epoch 199, Batch 49/105 → Batch Loss: -0.0281
#   Epoch 199, Batch 50/105 → Batch Loss: -0.1652
#   Epoch 199, Batch 51/105 → Batch Loss: 0.1917
#   Epoch 199, Batch 52/105 → Batch Loss: -0.1233
#   Epoch 199, Batch 53/105 → Batch Loss: -0.1070
#   Epoch 199, Batch 54/105 → Batch Loss: -0.0711
#   Epoch 199, Batch 55/105 → Batch Loss: -0.1469
#   Epoch 199, Batch 56/105 → Batch Loss: -0.0566
#   Epoch 199, Batch 57/105 → Batch Loss: -0.1028
#   Epoch 199, Batch 58/105 → Batch Loss: -0.0178
#   Epoch 199, Batch 59/105 → Batch Loss: -0.0032
#   Epoch 199, Batch 60/105 → Batch Loss: -0.1133
#   Epoch 199, Batch 61/105 → Batch Loss: 0.0361
#   Epoch 199, Batch 62/105 → Batch Loss: -0.0499
#   Epoch 199, Batch 63/105 → Batch Loss: 0.1232
#   Epoch 199, Batch 64/105 → Batch Loss: 0.0343
#   Epoch 199, Batch 65/105 → Batch Loss: -0.0069
#   Epoch 199, Batch 66/105 → Batch Loss: -0.0386
#   Epoch 199, Batch 67/105 → Batch Loss: -0.0112
#   Epoch 199, Batch 68/105 → Batch Loss: -0.0109
#   Epoch 199, Batch 69/105 → Batch Loss: -0.0567
#   Epoch 199, Batch 70/105 → Batch Loss: -0.0716
#   Epoch 199, Batch 71/105 → Batch Loss: -0.0771
#   Epoch 199, Batch 72/105 → Batch Loss: -0.0503
#   Epoch 199, Batch 73/105 → Batch Loss: -0.1277
#   Epoch 199, Batch 74/105 → Batch Loss: -0.0866
#   Epoch 199, Batch 75/105 → Batch Loss: 0.0205
#   Epoch 199, Batch 76/105 → Batch Loss: -0.0798
#   Epoch 199, Batch 77/105 → Batch Loss: -0.0263
#   Epoch 199, Batch 78/105 → Batch Loss: -0.0649
#   Epoch 199, Batch 79/105 → Batch Loss: -0.1221
#   Epoch 199, Batch 80/105 → Batch Loss: -0.0494
#   Epoch 199, Batch 81/105 → Batch Loss: -0.0310
#   Epoch 199, Batch 82/105 → Batch Loss: -0.0690
#   Epoch 199, Batch 83/105 → Batch Loss: 0.0117
#   Epoch 199, Batch 84/105 → Batch Loss: -0.0028
#   Epoch 199, Batch 85/105 → Batch Loss: 0.2725
#   Epoch 199, Batch 86/105 → Batch Loss: 0.0393
#   Epoch 199, Batch 87/105 → Batch Loss: -0.0585
#   Epoch 199, Batch 88/105 → Batch Loss: -0.1336
#   Epoch 199, Batch 89/105 → Batch Loss: -0.1085
#   Epoch 199, Batch 90/105 → Batch Loss: -0.0887
#   Epoch 199, Batch 91/105 → Batch Loss: 0.0490
#   Epoch 199, Batch 92/105 → Batch Loss: -0.1541
#   Epoch 199, Batch 93/105 → Batch Loss: 0.0427
#   Epoch 199, Batch 94/105 → Batch Loss: -0.0881
#   Epoch 199, Batch 95/105 → Batch Loss: -0.1109
#   Epoch 199, Batch 96/105 → Batch Loss: -0.0695
#   Epoch 199, Batch 97/105 → Batch Loss: -0.0686
#   Epoch 199, Batch 98/105 → Batch Loss: -0.0673
#   Epoch 199, Batch 99/105 → Batch Loss: -0.0776
#   Epoch 199, Batch 100/105 → Batch Loss: -0.0955
#   Epoch 199, Batch 101/105 → Batch Loss: -0.0362
#   Epoch 199, Batch 102/105 → Batch Loss: -0.0076
#   Epoch 199, Batch 103/105 → Batch Loss: -0.1368
#   Epoch 199, Batch 104/105 → Batch Loss: 0.0069
#   Epoch 199, Batch 105/105 → Batch Loss: -0.0592
#   Epoch 200, Batch 1/105 → Batch Loss: -0.0988
#   Epoch 200, Batch 2/105 → Batch Loss: 0.1024
#   Epoch 200, Batch 3/105 → Batch Loss: 0.2594
#   Epoch 200, Batch 4/105 → Batch Loss: -0.0516
#   Epoch 200, Batch 5/105 → Batch Loss: -0.1138
#   Epoch 200, Batch 6/105 → Batch Loss: -0.0427
#   Epoch 200, Batch 7/105 → Batch Loss: -0.1131
#   Epoch 200, Batch 8/105 → Batch Loss: -0.0755
#   Epoch 200, Batch 9/105 → Batch Loss: -0.0684
#   Epoch 200, Batch 10/105 → Batch Loss: -0.0040
#   Epoch 200, Batch 11/105 → Batch Loss: -0.0352
#   Epoch 200, Batch 12/105 → Batch Loss: -0.0971
#   Epoch 200, Batch 13/105 → Batch Loss: -0.0885
#   Epoch 200, Batch 14/105 → Batch Loss: -0.0225
#   Epoch 200, Batch 15/105 → Batch Loss: -0.1188
#   Epoch 200, Batch 16/105 → Batch Loss: -0.0239
#   Epoch 200, Batch 17/105 → Batch Loss: -0.1197
#   Epoch 200, Batch 18/105 → Batch Loss: -0.1336
#   Epoch 200, Batch 19/105 → Batch Loss: -0.0914
#   Epoch 200, Batch 20/105 → Batch Loss: -0.0482
#   Epoch 200, Batch 21/105 → Batch Loss: -0.1057
#   Epoch 200, Batch 22/105 → Batch Loss: -0.0263
#   Epoch 200, Batch 23/105 → Batch Loss: 0.0602
#   Epoch 200, Batch 24/105 → Batch Loss: -0.1085
#   Epoch 200, Batch 25/105 → Batch Loss: -0.0795
#   Epoch 200, Batch 26/105 → Batch Loss: -0.1032
#   Epoch 200, Batch 27/105 → Batch Loss: -0.1439
#   Epoch 200, Batch 28/105 → Batch Loss: 0.0467
#   Epoch 200, Batch 29/105 → Batch Loss: 0.0691
#   Epoch 200, Batch 30/105 → Batch Loss: -0.0057
#   Epoch 200, Batch 31/105 → Batch Loss: -0.0272
#   Epoch 200, Batch 32/105 → Batch Loss: -0.0772
#   Epoch 200, Batch 33/105 → Batch Loss: -0.0534
#   Epoch 200, Batch 34/105 → Batch Loss: -0.0192
#   Epoch 200, Batch 35/105 → Batch Loss: 0.1031
#   Epoch 200, Batch 36/105 → Batch Loss: -0.0990
#   Epoch 200, Batch 37/105 → Batch Loss: -0.0575
#   Epoch 200, Batch 38/105 → Batch Loss: -0.1446
#   Epoch 200, Batch 39/105 → Batch Loss: 0.0271
#   Epoch 200, Batch 40/105 → Batch Loss: -0.1972
#   Epoch 200, Batch 41/105 → Batch Loss: -0.0641
#   Epoch 200, Batch 42/105 → Batch Loss: 0.0047
#   Epoch 200, Batch 43/105 → Batch Loss: -0.0981
#   Epoch 200, Batch 44/105 → Batch Loss: 0.0756
#   Epoch 200, Batch 45/105 → Batch Loss: -0.0980
#   Epoch 200, Batch 46/105 → Batch Loss: -0.0779
#   Epoch 200, Batch 47/105 → Batch Loss: 0.0282
#   Epoch 200, Batch 48/105 → Batch Loss: -0.1133
#   Epoch 200, Batch 49/105 → Batch Loss: 0.0595
#   Epoch 200, Batch 50/105 → Batch Loss: -0.1090
#   Epoch 200, Batch 51/105 → Batch Loss: -0.0331
#   Epoch 200, Batch 52/105 → Batch Loss: -0.0917
#   Epoch 200, Batch 53/105 → Batch Loss: 0.0684
#   Epoch 200, Batch 54/105 → Batch Loss: -0.0221
#   Epoch 200, Batch 55/105 → Batch Loss: -0.0144
#   Epoch 200, Batch 56/105 → Batch Loss: -0.1039
#   Epoch 200, Batch 57/105 → Batch Loss: -0.0842
#   Epoch 200, Batch 58/105 → Batch Loss: -0.0301
#   Epoch 200, Batch 59/105 → Batch Loss: -0.0519
#   Epoch 200, Batch 60/105 → Batch Loss: 0.0497
#   Epoch 200, Batch 61/105 → Batch Loss: -0.0866
#   Epoch 200, Batch 62/105 → Batch Loss: 0.0407
#   Epoch 200, Batch 63/105 → Batch Loss: -0.0092
#   Epoch 200, Batch 64/105 → Batch Loss: -0.0859
#   Epoch 200, Batch 65/105 → Batch Loss: -0.0507
#   Epoch 200, Batch 66/105 → Batch Loss: 0.0417
#   Epoch 200, Batch 67/105 → Batch Loss: 0.0251
#   Epoch 200, Batch 68/105 → Batch Loss: 0.0321
#   Epoch 200, Batch 69/105 → Batch Loss: -0.1198
#   Epoch 200, Batch 70/105 → Batch Loss: 0.0130
#   Epoch 200, Batch 71/105 → Batch Loss: -0.0881
#   Epoch 200, Batch 72/105 → Batch Loss: -0.0967
#   Epoch 200, Batch 73/105 → Batch Loss: 0.0283
#   Epoch 200, Batch 74/105 → Batch Loss: -0.1071
#   Epoch 200, Batch 75/105 → Batch Loss: -0.0097
#   Epoch 200, Batch 76/105 → Batch Loss: -0.0474
#   Epoch 200, Batch 77/105 → Batch Loss: -0.0824
#   Epoch 200, Batch 78/105 → Batch Loss: -0.0430
#   Epoch 200, Batch 79/105 → Batch Loss: 0.0592
#   Epoch 200, Batch 80/105 → Batch Loss: -0.0373
#   Epoch 200, Batch 81/105 → Batch Loss: -0.0546
#   Epoch 200, Batch 82/105 → Batch Loss: -0.0686
#   Epoch 200, Batch 83/105 → Batch Loss: -0.0820
#   Epoch 200, Batch 84/105 → Batch Loss: -0.0618
#   Epoch 200, Batch 85/105 → Batch Loss: -0.1542
#   Epoch 200, Batch 86/105 → Batch Loss: 0.0126
#   Epoch 200, Batch 87/105 → Batch Loss: -0.0585
#   Epoch 200, Batch 88/105 → Batch Loss: 0.0471
#   Epoch 200, Batch 89/105 → Batch Loss: -0.0670
#   Epoch 200, Batch 90/105 → Batch Loss: -0.0749
#   Epoch 200, Batch 91/105 → Batch Loss: -0.1111
#   Epoch 200, Batch 92/105 → Batch Loss: -0.0109
#   Epoch 200, Batch 93/105 → Batch Loss: -0.0255
#   Epoch 200, Batch 94/105 → Batch Loss: -0.1426
#   Epoch 200, Batch 95/105 → Batch Loss: -0.0168
#   Epoch 200, Batch 96/105 → Batch Loss: -0.0370
#   Epoch 200, Batch 97/105 → Batch Loss: -0.0889
#   Epoch 200, Batch 98/105 → Batch Loss: -0.1673
#   Epoch 200, Batch 99/105 → Batch Loss: -0.0086
#   Epoch 200, Batch 100/105 → Batch Loss: -0.0461
#   Epoch 200, Batch 101/105 → Batch Loss: -0.0945
#   Epoch 200, Batch 102/105 → Batch Loss: -0.0546
#   Epoch 200, Batch 103/105 → Batch Loss: -0.0770
#   Epoch 200, Batch 104/105 → Batch Loss: 0.0262
#   Epoch 200, Batch 105/105 → Batch Loss: 0.0516

# %%
torch.save({
    'w1': w1,
    'w2a': w2a,
    'w2c': w2c,
    'log_std': log_std
}, 'MLP_Feat_2.pth')

# %%
# Plot results after training
epochs_range = list(range(1, len(actor_loss_hist)+1))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4), sharex=True)

# 5.3.1 Actor Loss Over Epochs
ax1.plot(epochs_range, actor_loss_hist, marker='o')
ax1.set_title("Actor Loss Over Epochs")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Actor Loss")
ax1.grid(True)

# 5.3.3 Log-Probability of Actions
ax2.plot(epochs_range, logprob_hist, marker='o', color='tab:green')
ax2.set_title("Average Log-Probability Over Epochs")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Avg. Log-Probability")
ax2.grid(True)

plt.tight_layout()
plt.savefig("MLP_Features/actor_loss_and_logprob5.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[126], line 21
#      18 ax2.grid(True)
#      20 plt.tight_layout()
# ---> 21 plt.savefig("MLP_Features/actor_loss_and_logprob5.png", dpi=300)
#      22 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/miagauci/Documents/FYP_PPO/PyTorch/MLP_Features/MLP_Features/actor_loss_and_logprob5.png'

# %% [markdown]
# ### Trading Environment

# %%
class MultiStockEnvironment:
    def __init__(self, data, window_size, initial_cash=10000):
        self.data = data  # this is now the full data dict with all features
        self.window_size  = window_size
        self.initial_cash = float(initial_cash)
        self.tickers      = list(data.keys())
        self.reset()

    def reset(self):
        self.t = 0
        self.cash = self.initial_cash
        self.holdings = {t: 0.0 for t in self.tickers}
        self.portfolio_values = [self.initial_cash]
        self.done = False

        return {
            t: np.column_stack([
                self.data[t]["norm"][0:self.window_size],
                self.data[t]["ema"][0:self.window_size],
                self.data[t]["rsi"][0:self.window_size],
                self.data[t]["macd"][0:self.window_size],
                self.data[t]["bb_upper"][0:self.window_size],
                self.data[t]["bb_lower"][0:self.window_size],
            ])
            for t in self.tickers
        }

    def step(self, actions):
        # Liquidate negatives
        freed_cash = 0.0
        for t in self.tickers:
            if actions[t] < 0 and self.holdings[t] > 0:
                price = self.data[t]["raw"][self.t + self.window_size].item()
                freed_cash += self.holdings[t] * price
                self.holdings[t] = 0.0
        self.cash += freed_cash

        # Allocate positives
        pos_actions = {t: actions[t] for t in self.tickers if actions[t] > 0}
        total_pos   = sum(pos_actions.values())
        if total_pos > 0 and self.cash > 0:
            for t, a in pos_actions.items():
                weight = a / total_pos
                price = self.data[t]["raw"][self.t + self.window_size].item()
                buy_amount = self.cash * weight
                self.holdings[t] += buy_amount / price
            self.cash = 0.0

        # Compute portfolio value
        pv = self.cash
        for t in self.tickers:
            price = self.data[t]["raw"][self.t + self.window_size].item()
            pv += self.holdings[t] * price
        self.portfolio_values.append(pv)

        # Advance time
        self.t += 1
        if self.t + self.window_size >= len(self.data[self.tickers[0]]["raw"]):
            self.done = True

        # Next state
        next_states = None
        if not self.done:
            next_states = {
                t: np.column_stack([
                    self.data[t]["norm"][self.t : self.t + self.window_size],
                    self.data[t]["ema"][self.t : self.t + self.window_size],
                    self.data[t]["rsi"][self.t : self.t + self.window_size],
                    self.data[t]["macd"][self.t : self.t + self.window_size],
                    self.data[t]["bb_upper"][self.t : self.t + self.window_size],
                    self.data[t]["bb_lower"][self.t : self.t + self.window_size],
                ])
                for t in self.tickers
            }

        return next_states, pv, self.done, {}

# %% [markdown]
# ### buy and hold

# %%
class BuyAndHoldEnvironment:
    def __init__(self, raw_prices, initial_cash=10000):
        self.raw_prices = raw_prices
        self.initial_cash = initial_cash
        self.portfolio_values = []

    def run(self, start_index=30):
        # stack into shape (T,5)
        prices = np.stack([self.raw_prices[t] for t in tickers], axis=1)
        # equal allocation
        alloc = self.initial_cash / len(tickers)
        init_p = prices[start_index]            
        shares = alloc / init_p                 
        # build PV curve
        for p in prices[start_index+1:]:
            self.portfolio_values.append((shares * p).sum())

# %% [markdown]
# ### Simulate Agent with the trained MLP once

# %%
# Precompute price normalization stats (still needed for logging only)
mean_price = {t: raw_prices[t].mean() for t in tickers}
std_price  = {t: raw_prices[t].std()  for t in tickers}

# Instantiate the environment with full data (not just raw_prices)
env = MultiStockEnvironment(data, window_size=state_dim)
state_dict = env.reset()

day = 0
print("Starting multi-stock simulation...\n")

while not env.done:
    # Sample actions from current state
    actions = {}
    trades  = {}
    for t in tickers:
        win = state_dict[t]  # shape: (state_dim, 6)

        # Already normalized in data — just flatten
        st = torch.tensor(win, dtype=torch.float32).view(1, -1)  # shape: (1, 30)

        a_tensor, _ = get_action(st, w1, w2a, log_std)
        a_val       = a_tensor.item()
        actions[t]  = a_val

        if   a_val > 0 and env.holdings[t] == 0:
            trades[t] = "BUY"
        elif a_val < 0 and env.holdings[t] > 0:
            trades[t] = "SELL"
        else:
            trades[t] = "HOLD"

    # Step the environment
    next_states, port_val, done, _ = env.step(actions)

    # Log values
    cash = float(env.cash)
    prices = {t: float(raw_prices[t][day + state_dim]) for t in tickers}
    held   = {t: float(env.holdings[t]) for t in tickers}

    # Print summary and per-ticker details
    print(f"Day {day}: Cash = {cash:.2f}, Portfolio = {port_val:.2f}")
    for t in tickers:
        print(f"  {t:>6s} | Price = {prices[t]:6.2f} | "
              f"Action = {actions[t]:6.4f} | Trade = {trades[t]:>4s} | "
              f"Held = {held[t]:6.4f}")
    print("-" * 60)

    # advance
    state_dict = next_states
    day += 1

print(f"\nDone. Final portfolio value: {env.portfolio_values[-1]:.2f}")
# Out:
# Starting multi-stock simulation...
#
# Day 0: Cash = 0.00, Portfolio = 10000.00
#     AAPL | Price = 129.06 | Action = 1.4747 | Trade =  BUY | Held = 14.4313
#     MSFT | Price = 224.29 | Action = 2.4601 | Trade =  BUY | Held = 14.0160
#    GOOGL | Price =  87.89 | Action = -1.3816 | Trade = HOLD | Held = 0.0000
#     META | Price = 132.26 | Action = -0.7796 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  89.87 | Action = -1.4984 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 118.85 | Action = 1.0310 | Trade =  BUY | Held = 7.8261
#     NVDA | Price =  15.89 | Action = 1.7276 | Trade =  BUY | Held = 116.5080
# ------------------------------------------------------------
# Day 1: Cash = 0.00, Portfolio = 9988.49
#     AAPL | Price = 131.78 | Action = -1.8954 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 231.07 | Action = 0.2617 | Trade = HOLD | Held = 15.5538
#    GOOGL | Price =  90.97 | Action = -0.0155 | Trade = HOLD | Held = 0.0000
#     META | Price = 132.16 | Action = -0.3982 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  95.09 | Action = 1.4778 | Trade =  BUY | Held = 22.6938
#     TSLA | Price = 123.22 | Action = -1.0629 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  15.99 | Action = 0.6946 | Trade = HOLD | Held = 164.6104
# ------------------------------------------------------------
# Day 2: Cash = 0.00, Portfolio = 9921.72
#     AAPL | Price = 131.70 | Action = -3.2682 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 233.76 | Action = 1.2340 | Trade = HOLD | Held = 17.3359
#    GOOGL | Price =  90.59 | Action = 1.3699 | Trade =  BUY | Held = 5.4127
#     META | Price = 135.96 | Action = 0.8665 | Trade =  BUY | Held = 1.8272
#     AMZN | Price =  95.27 | Action = -2.9222 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 123.56 | Action = -0.8671 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  16.50 | Action = 2.5043 | Trade = HOLD | Held = 206.4830
# ------------------------------------------------------------
# Day 3: Cash = 0.00, Portfolio = 9682.51
#     AAPL | Price = 133.04 | Action = -0.3459 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 234.47 | Action = -0.1712 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  91.57 | Action = -0.6546 | Trade = SELL | Held = 0.0000
#     META | Price = 136.23 | Action = -0.2882 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  98.12 | Action = -2.0792 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 122.40 | Action = -1.4508 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  16.88 | Action = 1.1290 | Trade = HOLD | Held = 455.7308
# ------------------------------------------------------------
# Day 4: Cash = 0.00, Portfolio = 9920.64
#     AAPL | Price = 134.20 | Action = -1.8764 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 235.56 | Action = 0.5454 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  90.75 | Action = -1.2478 | Trade = HOLD | Held = 0.0000
#     META | Price = 134.62 | Action = -2.9876 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  96.05 | Action = -0.2042 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 131.49 | Action = 0.1918 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  17.69 | Action = 0.1627 | Trade = HOLD | Held = 455.7308
# ------------------------------------------------------------
# Day 5: Cash = 10459.30, Portfolio = 10459.30
#     AAPL | Price = 133.48 | Action = -1.8771 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 231.11 | Action = -0.1907 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  90.58 | Action = -0.4682 | Trade = HOLD | Held = 0.0000
#     META | Price = 132.29 | Action = -1.6396 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  95.46 | Action = -3.8092 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 128.78 | Action = -2.3622 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  17.36 | Action = -0.9250 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 6: Cash = 10459.30, Portfolio = 10459.30
#     AAPL | Price = 133.54 | Action = -3.0276 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 227.31 | Action = -0.2102 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  92.50 | Action = -1.2634 | Trade = HOLD | Held = 0.0000
#     META | Price = 135.41 | Action = -0.2592 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  93.68 | Action = -1.8930 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 127.17 | Action = -1.4434 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  16.75 | Action = -1.2623 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 7: Cash = 0.00, Portfolio = 10459.30
#     AAPL | Price = 136.11 | Action = 0.3196 | Trade =  BUY | Held = 11.0003
#     MSFT | Price = 235.44 | Action = 0.0566 | Trade =  BUY | Held = 1.1499
#    GOOGL | Price =  97.44 | Action = 0.2358 | Trade =  BUY | Held = 12.9907
#     META | Price = 138.61 | Action = 0.7710 | Trade =  BUY | Held = 23.5154
#     AMZN | Price =  97.25 | Action = 0.6166 | Trade =  BUY | Held = 32.8593
#     TSLA | Price = 133.42 | Action = -0.5335 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  17.82 | Action = -0.7798 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 8: Cash = 0.00, Portfolio = 10406.15
#     AAPL | Price = 139.31 | Action = 0.0347 | Trade = HOLD | Held = 11.0106
#     MSFT | Price = 237.75 | Action = -2.4184 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  99.20 | Action = 1.3335 | Trade = HOLD | Held = 13.6263
#     META | Price = 142.49 | Action = 0.7271 | Trade = HOLD | Held = 23.7044
#     AMZN | Price =  97.52 | Action = 1.7318 | Trade = HOLD | Held = 33.6557
#     TSLA | Price = 143.75 | Action = -3.1704 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  19.18 | Action = 2.6948 | Trade =  BUY | Held = 5.6374
# ------------------------------------------------------------
# Day 9: Cash = 10216.00, Portfolio = 10216.00
#     AAPL | Price = 140.71 | Action = -0.8612 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 237.22 | Action = -1.8371 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  97.12 | Action = -1.8624 | Trade = SELL | Held = 0.0000
#     META | Price = 142.36 | Action = -1.2664 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  96.32 | Action = -0.7566 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 143.89 | Action = -1.1384 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  19.25 | Action = -0.3411 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 10: Cash = 0.00, Portfolio = 10216.00
#     AAPL | Price = 140.05 | Action = -2.6820 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 235.82 | Action = -2.1689 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  94.65 | Action = 0.3819 | Trade =  BUY | Held = 19.0487
#     META | Price = 140.73 | Action = 1.8447 | Trade =  BUY | Held = 49.2536
#     AMZN | Price =  97.18 | Action = 0.0216 | Trade =  BUY | Held = 1.0263
#     TSLA | Price = 144.43 | Action = -1.7521 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  19.31 | Action = -1.1495 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 11: Cash = 0.00, Portfolio = 10246.71
#     AAPL | Price = 142.12 | Action = -1.3883 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 243.06 | Action = -0.6743 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  96.94 | Action = -0.0262 | Trade = SELL | Held = 0.0000
#     META | Price = 146.50 | Action = -1.9924 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  99.22 | Action = 1.8366 | Trade = HOLD | Held = 106.9371
#     TSLA | Price = 160.27 | Action = -2.7739 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  19.78 | Action = -0.6395 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 12: Cash = 0.00, Portfolio = 9998.62
#     AAPL | Price = 144.06 | Action = -1.0368 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 243.22 | Action = 0.0941 | Trade =  BUY | Held = 2.4178
#    GOOGL | Price =  98.78 | Action = -0.0372 | Trade = HOLD | Held = 0.0000
#     META | Price = 150.91 | Action = -0.3101 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 102.24 | Action = -1.0996 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 177.90 | Action = -1.9250 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  20.35 | Action = 1.4949 | Trade =  BUY | Held = 404.3178
# ------------------------------------------------------------
# Day 13: Cash = 0.00, Portfolio = 10087.70
#     AAPL | Price = 141.17 | Action = -3.8329 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 237.88 | Action = -0.7353 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  96.36 | Action = 0.3453 | Trade =  BUY | Held = 1.4909
#     META | Price = 146.26 | Action = 0.3114 | Trade =  BUY | Held = 0.7122
#     AMZN | Price = 100.55 | Action = -2.0875 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 166.66 | Action = -0.5200 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  19.14 | Action = 0.8841 | Trade = HOLD | Held = 418.8401
# ------------------------------------------------------------
# Day 14: Cash = 0.00, Portfolio = 9972.54
#     AAPL | Price = 142.44 | Action = -0.9627 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 242.88 | Action = 0.9360 | Trade =  BUY | Held = 0.2879
#    GOOGL | Price =  98.25 | Action = -0.6283 | Trade = SELL | Held = 0.0000
#     META | Price = 148.16 | Action = -0.8889 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 103.13 | Action = -0.6468 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 173.22 | Action = -1.4333 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  19.52 | Action = 2.4785 | Trade = HOLD | Held = 426.8947
# ------------------------------------------------------------
# Day 15: Cash = 0.00, Portfolio = 9750.72
#     AAPL | Price = 143.57 | Action = -0.6980 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 247.72 | Action = -0.3799 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  99.83 | Action = 0.3513 | Trade =  BUY | Held = 25.8359
#     META | Price = 152.28 | Action = 1.1249 | Trade =  BUY | Held = 43.0796
#     AMZN | Price = 105.15 | Action = -0.8146 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 181.41 | Action = -1.7239 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  20.92 | Action = -0.7130 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 16: Cash = 0.00, Portfolio = 9840.39
#     AAPL | Price = 148.89 | Action = -0.1174 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 259.33 | Action = -0.8356 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 107.10 | Action = 1.3064 | Trade = HOLD | Held = 81.0466
#     META | Price = 187.74 | Action = -0.5176 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 112.91 | Action = 0.0137 | Trade =  BUY | Held = 0.5729
#     TSLA | Price = 188.27 | Action = -0.8139 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  21.69 | Action = 0.6147 | Trade =  BUY | Held = 101.9939
# ------------------------------------------------------------
# Day 17: Cash = 0.00, Portfolio = 10033.61
#     AAPL | Price = 152.52 | Action = 0.8458 | Trade =  BUY | Held = 3.5287
#     MSFT | Price = 253.21 | Action = 1.0849 | Trade =  BUY | Held = 2.6946
#    GOOGL | Price = 104.16 | Action = 0.0845 | Trade = HOLD | Held = 81.6122
#     META | Price = 185.51 | Action = -0.8175 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 103.39 | Action = 1.8925 | Trade = HOLD | Held = 12.9965
#     TSLA | Price = 189.98 | Action = -2.2157 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  21.08 | Action = -0.6033 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 18: Cash = 0.00, Portfolio = 10152.68
#     AAPL | Price = 149.79 | Action = 0.0709 | Trade = HOLD | Held = 3.5287
#     MSFT | Price = 251.66 | Action = 0.1357 | Trade = HOLD | Held = 2.6946
#    GOOGL | Price = 102.29 | Action = 1.0069 | Trade = HOLD | Held = 81.6122
#     META | Price = 185.04 | Action = 1.6810 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 102.18 | Action = 0.8703 | Trade = HOLD | Held = 12.9965
#     TSLA | Price = 194.76 | Action = -2.0559 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  21.07 | Action = -0.2439 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 19: Cash = 0.00, Portfolio = 10032.07
#     AAPL | Price = 152.67 | Action = -1.0624 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 262.23 | Action = -0.4591 | Trade = SELL | Held = 0.0000
#    GOOGL | Price = 107.00 | Action = -1.0515 | Trade = SELL | Held = 0.0000
#     META | Price = 190.57 | Action = 0.4175 | Trade =  BUY | Held = 9.2773
#     AMZN | Price = 102.11 | Action = 1.4930 | Trade = HOLD | Held = 78.0690
#     TSLA | Price = 196.81 | Action = -1.3734 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  22.15 | Action = 0.2517 | Trade =  BUY | Held = 44.1011
# ------------------------------------------------------------
# Day 20: Cash = 0.00, Portfolio = 10104.55
#     AAPL | Price = 149.98 | Action = -1.5041 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 261.42 | Action = 0.1208 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  98.78 | Action = 1.9381 | Trade =  BUY | Held = 0.0000
#     META | Price = 182.43 | Action = 0.4543 | Trade = HOLD | Held = 9.2773
#     AMZN | Price = 100.05 | Action = 1.1878 | Trade = HOLD | Held = 78.0690
#     TSLA | Price = 201.29 | Action = -4.5471 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  22.19 | Action = 0.0972 | Trade = HOLD | Held = 44.1011
# ------------------------------------------------------------
# Day 21: Cash = 0.00, Portfolio = 9911.08
#     AAPL | Price = 148.94 | Action = -0.0334 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 258.37 | Action = 0.5049 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  94.44 | Action = 0.0652 | Trade =  BUY | Held = 0.0000
#     META | Price = 176.95 | Action = 0.6542 | Trade = HOLD | Held = 9.2773
#     AMZN | Price =  98.24 | Action = 0.5123 | Trade = HOLD | Held = 78.0690
#     TSLA | Price = 207.32 | Action = -2.2667 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  22.32 | Action = 0.5131 | Trade = HOLD | Held = 44.1011
# ------------------------------------------------------------
# Day 22: Cash = 0.00, Portfolio = 9751.55
#     AAPL | Price = 149.31 | Action = -0.4766 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 257.86 | Action = 0.8300 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  94.01 | Action = 1.0504 | Trade =  BUY | Held = 0.0000
#     META | Price = 173.20 | Action = 1.4571 | Trade = HOLD | Held = 9.2773
#     AMZN | Price =  97.61 | Action = 1.3552 | Trade = HOLD | Held = 78.0690
#     TSLA | Price = 196.89 | Action = -0.9017 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  21.25 | Action = 1.5243 | Trade = HOLD | Held = 44.1011
# ------------------------------------------------------------
# Day 23: Cash = 0.00, Portfolio = 9897.13
#     AAPL | Price = 152.11 | Action = -1.2424 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 265.92 | Action = -2.0037 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  94.05 | Action = -0.2954 | Trade = HOLD | Held = 0.0000
#     META | Price = 178.45 | Action = 1.2749 | Trade = HOLD | Held = 44.3899
#     AMZN | Price =  99.54 | Action = -0.8481 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 194.64 | Action = -2.1472 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  21.77 | Action = 0.1814 | Trade = HOLD | Held = 83.2616
# ------------------------------------------------------------
# Day 24: Cash = 0.00, Portfolio = 10567.62
#     AAPL | Price = 151.47 | Action = 0.0823 | Trade =  BUY | Held = 0.0000
#     MSFT | Price = 266.75 | Action = 0.3209 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  94.12 | Action = 2.6143 | Trade =  BUY | Held = 0.0000
#     META | Price = 178.50 | Action = 0.7416 | Trade = HOLD | Held = 44.3899
#     AMZN | Price =  99.70 | Action = 0.3189 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 209.25 | Action = -0.9012 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  22.95 | Action = 0.5656 | Trade = HOLD | Held = 83.2616
# ------------------------------------------------------------
# Day 25: Cash = 0.00, Portfolio = 10746.02
#     AAPL | Price = 153.58 | Action = 1.3346 | Trade =  BUY | Held = 12.9597
#     MSFT | Price = 264.62 | Action = -0.9371 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  96.36 | Action = 1.4879 | Trade =  BUY | Held = 22.8758
#     META | Price = 176.19 | Action = -0.3178 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 101.16 | Action = -0.4632 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 214.24 | Action = 1.1436 | Trade =  BUY | Held = 9.3088
#     NVDA | Price =  22.74 | Action = 1.9775 | Trade = HOLD | Held = 203.2344
# ------------------------------------------------------------
# Day 26: Cash = 0.00, Portfolio = 11179.31
#     AAPL | Price = 151.98 | Action = -1.0781 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 257.57 | Action = -1.7796 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  94.94 | Action = -2.0615 | Trade = SELL | Held = 0.0000
#     META | Price = 171.50 | Action = 1.5819 | Trade =  BUY | Held = 7.3749
#     AMZN | Price =  98.15 | Action = 1.2124 | Trade =  BUY | Held = 11.5156
#     TSLA | Price = 202.04 | Action = 0.1805 | Trade = HOLD | Held = 10.2404
#     NVDA | Price =  21.98 | Action = 1.5277 | Trade = HOLD | Held = 260.1077
# ------------------------------------------------------------
# Day 27: Cash = 0.00, Portfolio = 11105.27
#     AAPL | Price = 150.83 | Action = -0.9282 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 253.55 | Action = 0.4972 | Trade =  BUY | Held = 0.7783
#    GOOGL | Price =  93.79 | Action = -0.4705 | Trade = HOLD | Held = 0.0000
#     META | Price = 171.94 | Action = 0.5817 | Trade = HOLD | Held = 8.6598
#     AMZN | Price =  97.20 | Action = 1.1947 | Trade = HOLD | Held = 16.7041
#     TSLA | Price = 208.31 | Action = -1.1822 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  21.37 | Action = 2.0187 | Trade = HOLD | Held = 293.8559
# ------------------------------------------------------------
# Day 28: Cash = 0.00, Portfolio = 11149.38
#     AAPL | Price = 146.81 | Action = 0.6513 | Trade =  BUY | Held = 0.0000
#     MSFT | Price = 248.26 | Action = 1.2061 | Trade = HOLD | Held = 0.7783
#    GOOGL | Price =  91.24 | Action = -1.2667 | Trade = HOLD | Held = 0.0000
#     META | Price = 171.14 | Action = 1.0306 | Trade = HOLD | Held = 8.6598
#     AMZN | Price =  94.58 | Action = 2.4402 | Trade = HOLD | Held = 16.7041
#     TSLA | Price = 197.37 | Action = 0.7668 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  20.64 | Action = 0.0003 | Trade = HOLD | Held = 293.8559
# ------------------------------------------------------------
# Day 29: Cash = 0.00, Portfolio = 11324.27
#     AAPL | Price = 147.23 | Action = -1.4715 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 247.12 | Action = -0.3327 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  91.10 | Action = 0.7903 | Trade =  BUY | Held = 4.5649
#     META | Price = 170.19 | Action = 1.7196 | Trade = HOLD | Held = 13.8122
#     AMZN | Price =  95.79 | Action = -1.5136 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 200.86 | Action = -0.9195 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  20.74 | Action = 0.6274 | Trade = HOLD | Held = 308.2918
# ------------------------------------------------------------
# Day 30: Cash = 0.00, Portfolio = 11367.83
#     AAPL | Price = 147.71 | Action = -0.6249 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 250.32 | Action = 1.3881 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  90.35 | Action = 1.2516 | Trade = HOLD | Held = 4.5649
#     META | Price = 171.10 | Action = 0.4339 | Trade = HOLD | Held = 13.8122
#     AMZN | Price =  95.82 | Action = 0.4463 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 202.07 | Action = 0.8535 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  23.64 | Action = 1.0574 | Trade = HOLD | Held = 308.2918
# ------------------------------------------------------------
# Day 31: Cash = 0.00, Portfolio = 11662.09
#     AAPL | Price = 145.06 | Action = -0.4469 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 244.87 | Action = 1.1578 | Trade =  BUY | Held = 7.5751
#    GOOGL | Price =  88.60 | Action = 1.7954 | Trade = HOLD | Held = 35.0932
#     META | Price = 169.46 | Action = 1.3442 | Trade = HOLD | Held = 25.6212
#     AMZN | Price =  93.50 | Action = 0.2159 | Trade =  BUY | Held = 3.9046
#     TSLA | Price = 196.88 | Action = 0.1798 | Trade =  BUY | Held = 1.6699
#     NVDA | Price =  23.27 | Action = -0.6682 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 32: Cash = 0.00, Portfolio = 11716.96
#     AAPL | Price = 146.25 | Action = -0.7425 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 245.79 | Action = 0.6634 | Trade = HOLD | Held = 7.8088
#    GOOGL | Price =  89.33 | Action = 1.6600 | Trade = HOLD | Held = 36.6312
#     META | Price = 168.61 | Action = 0.2506 | Trade = HOLD | Held = 25.7400
#     AMZN | Price =  93.76 | Action = -1.7066 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 207.63 | Action = 1.3718 | Trade = HOLD | Held = 2.3695
#     NVDA | Price =  23.48 | Action = -0.2220 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 33: Cash = 0.00, Portfolio = 11498.47
#     AAPL | Price = 145.75 | Action = -0.2287 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 245.07 | Action = 0.6660 | Trade = HOLD | Held = 13.9266
#    GOOGL | Price =  89.52 | Action = 0.3587 | Trade = HOLD | Held = 45.4166
#     META | Price = 173.99 | Action = -0.4658 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  94.23 | Action = 0.1258 | Trade =  BUY | Held = 3.1999
#     TSLA | Price = 205.71 | Action = 0.2023 | Trade = HOLD | Held = 5.0005
#     NVDA | Price =  23.20 | Action = 0.7289 | Trade =  BUY | Held = 68.5786
# ------------------------------------------------------------
# Day 34: Cash = 0.00, Portfolio = 11394.22
#     AAPL | Price = 143.67 | Action = 0.5860 | Trade =  BUY | Held = 17.6888
#     MSFT | Price = 241.97 | Action = 0.1354 | Trade = HOLD | Held = 16.2828
#    GOOGL | Price =  89.82 | Action = -0.2285 | Trade = SELL | Held = 0.0000
#     META | Price = 172.47 | Action = -0.1663 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  92.17 | Action = 0.8337 | Trade = HOLD | Held = 43.5394
#     TSLA | Price = 202.77 | Action = -0.5372 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  22.68 | Action = -0.7388 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 35: Cash = 0.00, Portfolio = 11664.32
#     AAPL | Price = 144.26 | Action = 0.6432 | Trade = HOLD | Held = 17.6888
#     MSFT | Price = 246.73 | Action = 1.6664 | Trade = HOLD | Held = 16.2828
#    GOOGL | Price =  91.45 | Action = 0.4961 | Trade =  BUY | Held = 0.0000
#     META | Price = 173.58 | Action = -1.4346 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  92.13 | Action = 1.2507 | Trade = HOLD | Held = 43.5394
#     TSLA | Price = 190.90 | Action = 1.7768 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  23.29 | Action = 0.9707 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 36: Cash = 0.00, Portfolio = 11824.95
#     AAPL | Price = 149.33 | Action = 0.8242 | Trade = HOLD | Held = 20.9812
#     MSFT | Price = 250.83 | Action = -0.1821 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  93.09 | Action = 2.2127 | Trade =  BUY | Held = 14.1479
#     META | Price = 184.24 | Action = 2.6500 | Trade =  BUY | Held = 8.2207
#     AMZN | Price =  94.90 | Action = 1.4000 | Trade = HOLD | Held = 52.3405
#     TSLA | Price = 197.79 | Action = -2.3022 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  23.87 | Action = -0.7386 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 37: Cash = 0.00, Portfolio = 12018.62
#     AAPL | Price = 152.09 | Action = 1.5612 | Trade = HOLD | Held = 25.3645
#     MSFT | Price = 252.39 | Action = -0.0000 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  94.56 | Action = 0.9613 | Trade = HOLD | Held = 18.4154
#     META | Price = 183.89 | Action = -0.0815 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  93.75 | Action = 1.2629 | Trade = HOLD | Held = 57.9374
#     TSLA | Price = 193.81 | Action = -0.7803 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  23.53 | Action = -0.2161 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 38: Cash = 0.00, Portfolio = 12011.02
#     AAPL | Price = 149.89 | Action = 0.6465 | Trade = HOLD | Held = 25.3645
#     MSFT | Price = 249.71 | Action = 1.5054 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  93.30 | Action = 1.3762 | Trade = HOLD | Held = 18.4154
#     META | Price = 183.50 | Action = -0.9705 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  93.55 | Action = 0.0330 | Trade = HOLD | Held = 57.9374
#     TSLA | Price = 187.71 | Action = -0.9931 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  23.27 | Action = -0.0445 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 39: Cash = 0.00, Portfolio = 12093.29
#     AAPL | Price = 151.15 | Action = -0.6568 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 249.27 | Action = 1.1990 | Trade =  BUY | Held = 20.1146
#    GOOGL | Price =  93.69 | Action = -0.4770 | Trade = SELL | Held = 0.0000
#     META | Price = 183.96 | Action = -1.2252 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  93.92 | Action = -0.5817 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 182.00 | Action = 1.0512 | Trade =  BUY | Held = 25.8386
#     NVDA | Price =  24.16 | Action = 0.3046 | Trade =  BUY | Held = 52.5510
# ------------------------------------------------------------
# Day 40: Cash = 0.00, Portfolio = 11824.71
#     AAPL | Price = 148.89 | Action = 2.0366 | Trade =  BUY | Held = 37.2520
#     MSFT | Price = 247.91 | Action = -0.7749 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  91.77 | Action = -0.0586 | Trade = HOLD | Held = 0.0000
#     META | Price = 180.70 | Action = 1.9560 | Trade =  BUY | Held = 27.5436
#     AMZN | Price =  92.25 | Action = -0.5927 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 172.92 | Action = -1.6663 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  23.42 | Action = -0.2896 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 41: Cash = 0.00, Portfolio = 11984.41
#     AAPL | Price = 146.82 | Action = -1.9895 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 244.25 | Action = -1.0318 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  90.09 | Action = 1.9791 | Trade =  BUY | Held = 35.1268
#     META | Price = 178.53 | Action = 0.1837 | Trade = HOLD | Held = 29.1786
#     AMZN | Price =  90.73 | Action = 1.0077 | Trade =  BUY | Held = 18.8867
#     TSLA | Price = 173.44 | Action = -0.1254 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  22.95 | Action = -0.7948 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 42: Cash = 0.00, Portfolio = 11878.18
#     AAPL | Price = 148.77 | Action = -0.1530 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 249.49 | Action = -0.3995 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  90.57 | Action = 1.2805 | Trade = HOLD | Held = 35.1268
#     META | Price = 179.91 | Action = 0.4793 | Trade = HOLD | Held = 29.1786
#     AMZN | Price =  92.43 | Action = 0.5127 | Trade = HOLD | Held = 18.8867
#     TSLA | Price = 174.48 | Action = -1.6991 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  22.95 | Action = 1.2011 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 43: Cash = 0.00, Portfolio = 11771.50
#     AAPL | Price = 150.87 | Action = -1.2428 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 256.24 | Action = 0.0718 | Trade =  BUY | Held = 5.6009
#    GOOGL | Price =  93.41 | Action = -1.4234 | Trade = SELL | Held = 0.0000
#     META | Price = 192.96 | Action = -0.2147 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  94.88 | Action = -1.2326 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 183.26 | Action = 0.4715 | Trade =  BUY | Held = 54.6873
#     NVDA | Price =  24.05 | Action = -2.3208 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 44: Cash = 0.00, Portfolio = 11433.34
#     AAPL | Price = 151.26 | Action = -0.8921 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 260.81 | Action = -1.6000 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  95.54 | Action = -2.3776 | Trade = HOLD | Held = 0.0000
#     META | Price = 196.67 | Action = 0.0297 | Trade =  BUY | Held = 0.9873
#     AMZN | Price =  96.20 | Action = 1.3665 | Trade =  BUY | Held = 98.9181
#     TSLA | Price = 180.45 | Action = -0.8274 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  24.21 | Action = 0.2183 | Trade =  BUY | Held = 58.3947
# ------------------------------------------------------------
# Day 45: Cash = 0.00, Portfolio = 11889.76
#     AAPL | Price = 154.09 | Action = -0.9836 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 271.38 | Action = -3.1626 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  99.72 | Action = 1.0525 | Trade =  BUY | Held = 0.7851
#     META | Price = 203.81 | Action = -0.9776 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 100.04 | Action = 0.9261 | Trade = HOLD | Held = 99.6386
#     TSLA | Price = 184.13 | Action = -0.3444 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  25.52 | Action = 0.7374 | Trade = HOLD | Held = 60.6160
# ------------------------------------------------------------
# Day 46: Cash = 0.00, Portfolio = 11919.72
#     AAPL | Price = 153.25 | Action = -0.6679 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 274.55 | Action = -1.5226 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 101.01 | Action = -2.3839 | Trade = SELL | Held = 0.0000
#     META | Price = 194.54 | Action = -0.6340 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  98.95 | Action = 1.3370 | Trade = HOLD | Held = 107.3629
#     TSLA | Price = 180.13 | Action = 1.5432 | Trade =  BUY | Held = 4.9402
#     NVDA | Price =  25.71 | Action = -0.4419 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 47: Cash = 0.00, Portfolio = 11954.49
#     AAPL | Price = 155.62 | Action = 0.7286 | Trade =  BUY | Held = 31.6810
#     MSFT | Price = 267.48 | Action = -2.6974 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 100.62 | Action = 0.1566 | Trade =  BUY | Held = 10.5594
#     META | Price = 196.73 | Action = 0.7977 | Trade =  BUY | Held = 26.0334
#     AMZN | Price =  97.71 | Action = -1.0819 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 183.25 | Action = -0.4794 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  25.88 | Action = -2.3053 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 48: Cash = 0.00, Portfolio = 11952.79
#     AAPL | Price = 157.48 | Action = -0.2068 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 269.00 | Action = -1.3051 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 104.29 | Action = -1.1337 | Trade = SELL | Held = 0.0000
#     META | Price = 201.06 | Action = -0.1020 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 100.61 | Action = -0.3099 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 197.58 | Action = 0.9603 | Trade =  BUY | Held = 64.8515
#     NVDA | Price =  26.18 | Action = -2.5212 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 49: Cash = 0.00, Portfolio = 11711.54
#     AAPL | Price = 156.05 | Action = -1.2789 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 267.54 | Action = -1.0624 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 102.75 | Action = 0.1472 | Trade =  BUY | Held = 0.0000
#     META | Price = 198.72 | Action = 0.6522 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.70 | Action = 0.7021 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 191.15 | Action = 0.7208 | Trade = HOLD | Held = 64.8515
#     NVDA | Price =  26.45 | Action = -0.2073 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 50: Cash = 0.00, Portfolio = 10570.15
#     AAPL | Price = 157.14 | Action = -0.2914 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 272.81 | Action = -2.3327 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 104.97 | Action = -1.8099 | Trade = HOLD | Held = 0.0000
#     META | Price = 203.17 | Action = 0.3311 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.71 | Action = 1.5803 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 192.22 | Action = 0.6867 | Trade = HOLD | Held = 64.8515
#     NVDA | Price =  27.17 | Action = -1.3082 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 51: Cash = 0.00, Portfolio = 10705.69
#     AAPL | Price = 158.44 | Action = 0.4649 | Trade =  BUY | Held = 0.0000
#     MSFT | Price = 275.67 | Action = -0.8288 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 104.81 | Action = -0.1693 | Trade = HOLD | Held = 0.0000
#     META | Price = 204.89 | Action = 0.1645 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.13 | Action = 0.9053 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 190.41 | Action = 0.7583 | Trade = HOLD | Held = 64.8515
#     NVDA | Price =  26.76 | Action = -1.2691 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 52: Cash = 0.00, Portfolio = 10541.62
#     AAPL | Price = 156.49 | Action = 0.0205 | Trade =  BUY | Held = 3.0704
#     MSFT | Price = 271.55 | Action = -0.7370 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 101.85 | Action = -0.2085 | Trade = HOLD | Held = 0.0000
#     META | Price = 201.73 | Action = -0.6242 | Trade = HOLD | Held = 0.0000
#     AMZN | Price =  98.04 | Action = 0.4092 | Trade =  BUY | Held = 94.5270
#     TSLA | Price = 191.81 | Action = -0.5311 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  26.51 | Action = -0.2055 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 53: Cash = 0.00, Portfolio = 10192.80
#     AAPL | Price = 155.87 | Action = -1.7609 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 270.42 | Action = -1.2268 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 100.43 | Action = -0.2231 | Trade = HOLD | Held = 0.0000
#     META | Price = 199.59 | Action = 0.0118 | Trade =  BUY | Held = 0.0133
#     AMZN | Price =  97.24 | Action = 1.1098 | Trade = HOLD | Held = 97.0473
#     TSLA | Price = 189.19 | Action = 0.7892 | Trade =  BUY | Held = 1.1441
#     NVDA | Price =  26.39 | Action = 0.2236 | Trade =  BUY | Held = 1.9866
# ------------------------------------------------------------
# Day 54: Cash = 0.00, Portfolio = 10420.21
#     AAPL | Price = 158.96 | Action = -0.8854 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 275.61 | Action = 0.0808 | Trade =  BUY | Held = 0.0002
#    GOOGL | Price = 100.79 | Action = 0.8356 | Trade =  BUY | Held = 0.0059
#     META | Price = 204.23 | Action = -0.2464 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 100.25 | Action = 1.9994 | Trade = HOLD | Held = 97.0611
#     TSLA | Price = 193.88 | Action = 0.5207 | Trade = HOLD | Held = 1.1466
#     NVDA | Price =  26.96 | Action = 0.3785 | Trade = HOLD | Held = 1.9968
# ------------------------------------------------------------
# Day 55: Cash = 0.00, Portfolio = 10897.94
#     AAPL | Price = 160.53 | Action = 0.4729 | Trade =  BUY | Held = 0.0464
#     MSFT | Price = 279.09 | Action = 0.8395 | Trade = HOLD | Held = 0.0459
#    GOOGL | Price = 100.29 | Action = 0.1509 | Trade = HOLD | Held = 0.0289
#     META | Price = 206.71 | Action = -1.9136 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 102.00 | Action = 0.3001 | Trade = HOLD | Held = 97.1057
#     TSLA | Price = 195.28 | Action = 1.5656 | Trade = HOLD | Held = 1.3061
#     NVDA | Price =  27.36 | Action = -1.5251 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 56: Cash = 0.00, Portfolio = 10479.13
#     AAPL | Price = 163.04 | Action = -0.5151 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 283.27 | Action = 0.9380 | Trade = HOLD | Held = 9.3572
#    GOOGL | Price = 103.11 | Action = 1.7917 | Trade = HOLD | Held = 50.3534
#     META | Price = 210.78 | Action = -0.9134 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 103.29 | Action = -0.2908 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 207.46 | Action = 0.6897 | Trade = HOLD | Held = 13.8855
#     NVDA | Price =  27.76 | Action = -1.0340 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 57: Cash = 0.00, Portfolio = 10422.05
#     AAPL | Price = 164.30 | Action = 1.9863 | Trade =  BUY | Held = 3.5788
#     MSFT | Price = 282.22 | Action = 1.2877 | Trade = HOLD | Held = 10.6529
#    GOOGL | Price = 103.74 | Action = 0.4894 | Trade = HOLD | Held = 51.7410
#     META | Price = 211.91 | Action = 1.4295 | Trade =  BUY | Held = 1.7857
#     AMZN | Price = 102.41 | Action = 1.8762 | Trade =  BUY | Held = 5.5542
#     TSLA | Price = 194.77 | Action = -1.1824 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  27.94 | Action = 0.3689 | Trade =  BUY | Held = 3.8579
# ------------------------------------------------------------
# Day 58: Cash = 0.00, Portfolio = 10319.15
#     AAPL | Price = 163.76 | Action = 0.2366 | Trade = HOLD | Held = 38.5877
#     MSFT | Price = 282.17 | Action = -0.2734 | Trade = SELL | Held = 0.0000
#    GOOGL | Price = 104.10 | Action = -0.2040 | Trade = SELL | Held = 0.0000
#     META | Price = 213.55 | Action = -2.0518 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 103.95 | Action = -0.5630 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 192.58 | Action = 0.1577 | Trade =  BUY | Held = 24.2590
#     NVDA | Price =  27.43 | Action = -0.7401 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 59: Cash = 0.00, Portfolio = 10284.85
#     AAPL | Price = 161.91 | Action = 1.4074 | Trade = HOLD | Held = 38.5877
#     MSFT | Price = 279.38 | Action = 0.0601 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price = 103.85 | Action = -0.2639 | Trade = HOLD | Held = 0.0000
#     META | Price = 210.33 | Action = -0.6449 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 101.10 | Action = 1.8024 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 185.52 | Action = 1.1510 | Trade = HOLD | Held = 24.2590
#     NVDA | Price =  26.86 | Action = 1.5221 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 60: Cash = 0.00, Portfolio = 10235.83
#     AAPL | Price = 162.80 | Action = 0.4923 | Trade = HOLD | Held = 38.5877
#     MSFT | Price = 286.51 | Action = -1.3493 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 107.77 | Action = 2.4951 | Trade =  BUY | Held = 0.0000
#     META | Price = 214.92 | Action = 0.3019 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 102.06 | Action = 0.1147 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 185.06 | Action = 0.5049 | Trade = HOLD | Held = 24.2590
#     NVDA | Price =  27.02 | Action = -0.0200 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 61: Cash = 0.00, Portfolio = 10747.59
#     AAPL | Price = 160.20 | Action = 1.7034 | Trade = HOLD | Held = 38.5877
#     MSFT | Price = 284.34 | Action = -0.3663 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 105.81 | Action = -0.4481 | Trade = HOLD | Held = 0.0000
#     META | Price = 213.58 | Action = -0.6822 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 102.17 | Action = -0.1230 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 184.51 | Action = 0.1201 | Trade = HOLD | Held = 24.2590
#     NVDA | Price =  27.56 | Action = -0.6369 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 62: Cash = 0.00, Portfolio = 10786.88
#     AAPL | Price = 158.99 | Action = -0.3882 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 277.89 | Action = -0.1441 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 104.72 | Action = 0.2650 | Trade =  BUY | Held = 51.4733
#     META | Price = 212.68 | Action = 0.2534 | Trade =  BUY | Held = 22.7273
#     AMZN | Price =  99.92 | Action = -0.1723 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 186.79 | Action = -0.8430 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  27.15 | Action = -0.2460 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 63: Cash = 0.00, Portfolio = 10767.65
#     AAPL | Price = 158.29 | Action = 0.3249 | Trade =  BUY | Held = 5.4430
#     MSFT | Price = 278.54 | Action = -2.3105 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 104.02 | Action = -0.6669 | Trade = SELL | Held = 0.0000
#     META | Price = 212.83 | Action = 0.3799 | Trade = HOLD | Held = 27.3843
#     AMZN | Price =  97.83 | Action = 0.5005 | Trade =  BUY | Held = 13.3561
#     TSLA | Price = 180.54 | Action = 0.5375 | Trade =  BUY | Held = 9.0415
#     NVDA | Price =  26.48 | Action = 0.1877 | Trade =  BUY | Held = 18.7055
# ------------------------------------------------------------
# Day 64: Cash = 0.00, Portfolio = 10817.42
#     AAPL | Price = 163.69 | Action = -1.2904 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 284.78 | Action = -0.4652 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 106.79 | Action = 0.9553 | Trade =  BUY | Held = 14.2626
#     META | Price = 219.15 | Action = -0.2860 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 102.40 | Action = 1.0421 | Trade = HOLD | Held = 29.0419
#     TSLA | Price = 185.90 | Action = 2.0658 | Trade = HOLD | Held = 29.3702
#     NVDA | Price =  26.44 | Action = 0.3274 | Trade = HOLD | Held = 37.5171
# ------------------------------------------------------------
# Day 65: Cash = 0.00, Portfolio = 11036.01
#     AAPL | Price = 163.35 | Action = -0.2474 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 281.14 | Action = -2.3715 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 108.22 | Action = -0.3273 | Trade = SELL | Held = 0.0000
#     META | Price = 220.28 | Action = 1.8484 | Trade =  BUY | Held = 17.3204
#     AMZN | Price = 102.51 | Action = -0.2711 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 185.00 | Action = -0.6667 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  26.74 | Action = 2.6864 | Trade = HOLD | Held = 244.2207
# ------------------------------------------------------------
# Day 66: Cash = 0.00, Portfolio = 10943.82
#     AAPL | Price = 163.37 | Action = -2.4249 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 283.76 | Action = -2.0912 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 105.34 | Action = 0.7096 | Trade =  BUY | Held = 0.0000
#     META | Price = 217.67 | Action = 1.8128 | Trade = HOLD | Held = 17.3204
#     AMZN | Price = 102.74 | Action = 0.1807 | Trade =  BUY | Held = 0.0000
#     TSLA | Price = 187.04 | Action = -0.2742 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  26.98 | Action = 0.5335 | Trade = HOLD | Held = 244.2207
# ------------------------------------------------------------
# Day 67: Cash = 0.00, Portfolio = 11180.42
#     AAPL | Price = 164.59 | Action = -0.0849 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 283.34 | Action = -0.0311 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 103.88 | Action = 2.3115 | Trade =  BUY | Held = 86.8992
#     META | Price = 216.70 | Action = -0.6143 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 102.30 | Action = 0.2564 | Trade =  BUY | Held = 10.0373
#     TSLA | Price = 184.31 | Action = -0.3751 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  27.65 | Action = -0.2099 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 68: Cash = 0.00, Portfolio = 11461.64
#     AAPL | Price = 165.74 | Action = 1.9149 | Trade =  BUY | Held = 2.7955
#     MSFT | Price = 283.41 | Action = 0.6471 | Trade =  BUY | Held = 0.5254
#    GOOGL | Price = 103.56 | Action = 2.0146 | Trade = HOLD | Held = 91.1168
#     META | Price = 214.52 | Action = -0.2990 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 104.30 | Action = -0.2264 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 180.59 | Action = -1.6805 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  27.91 | Action = -0.7257 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 69: Cash = 0.00, Portfolio = 11585.34
#     AAPL | Price = 164.77 | Action = -1.0290 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 281.11 | Action = -2.6336 | Trade = SELL | Held = 0.0000
#    GOOGL | Price = 104.66 | Action = -0.8036 | Trade = SELL | Held = 0.0000
#     META | Price = 211.91 | Action = -0.5540 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 103.81 | Action = -1.2315 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 162.99 | Action = -0.3689 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  27.08 | Action = 2.7886 | Trade =  BUY | Held = 384.1762
# ------------------------------------------------------------
# Day 70: Cash = 0.00, Portfolio = 12161.19
#     AAPL | Price = 163.16 | Action = 0.1484 | Trade =  BUY | Held = 0.0000
#     MSFT | Price = 280.77 | Action = -3.2633 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 104.78 | Action = -0.8290 | Trade = HOLD | Held = 0.0000
#     META | Price = 211.73 | Action = -0.7102 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 106.96 | Action = -0.2474 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 165.08 | Action = -0.7308 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  27.10 | Action = 0.5528 | Trade = HOLD | Held = 384.1762
# ------------------------------------------------------------
# Day 71: Cash = 0.00, Portfolio = 12002.25
#     AAPL | Price = 163.46 | Action = 0.1413 | Trade =  BUY | Held = 69.2077
#     MSFT | Price = 276.85 | Action = -3.6355 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 105.34 | Action = -1.8266 | Trade = HOLD | Held = 0.0000
#     META | Price = 211.63 | Action = -1.1578 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 106.21 | Action = -0.6527 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 162.55 | Action = -1.1207 | Trade = HOLD | Held = 0.0000
#     NVDA | Price =  27.02 | Action = -1.5803 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 72: Cash = 0.00, Portfolio = 11936.47
#     AAPL | Price = 161.92 | Action = -1.3703 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 270.61 | Action = -1.1771 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 103.23 | Action = -0.8899 | Trade = HOLD | Held = 0.0000
#     META | Price = 206.42 | Action = -0.2326 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 102.57 | Action = -0.8585 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 160.67 | Action = 0.4945 | Trade =  BUY | Held = 63.1994
#     NVDA | Price =  26.22 | Action = -0.2837 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 73: Cash = 0.00, Portfolio = 11740.56
#     AAPL | Price = 161.91 | Action = -0.5712 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 290.21 | Action = 0.8678 | Trade =  BUY | Held = 9.8131
#    GOOGL | Price = 103.09 | Action = -2.4836 | Trade = HOLD | Held = 0.0000
#     META | Price = 208.26 | Action = 0.7686 | Trade =  BUY | Held = 10.9949
#     AMZN | Price = 104.98 | Action = 1.7081 | Trade =  BUY | Held = 52.1451
#     TSLA | Price = 153.75 | Action = -0.4746 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  26.94 | Action = -1.6618 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 74: Cash = 0.00, Portfolio = 11845.72
#     AAPL | Price = 166.51 | Action = -2.4787 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 299.51 | Action = -1.4328 | Trade = SELL | Held = 0.0000
#    GOOGL | Price = 106.95 | Action = -3.1223 | Trade = HOLD | Held = 0.0000
#     META | Price = 237.26 | Action = 0.8762 | Trade = HOLD | Held = 23.5754
#     AMZN | Price = 109.82 | Action = -0.7177 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 160.19 | Action = 0.3347 | Trade =  BUY | Held = 6.5118
#     NVDA | Price =  27.21 | Action = 1.3520 | Trade =  BUY | Held = 157.6720
# ------------------------------------------------------------
# Day 75: Cash = 0.00, Portfolio = 13110.09
#     AAPL | Price = 167.77 | Action = -1.3286 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 301.90 | Action = -1.9341 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 106.70 | Action = -3.8121 | Trade = HOLD | Held = 0.0000
#     META | Price = 239.01 | Action = -0.7706 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 105.45 | Action = -1.1597 | Trade = HOLD | Held = 0.0000
# ...
# Day 453: Cash = 0.00, Portfolio = 21980.85
#     AAPL | Price = 232.85 | Action = 1.1560 | Trade =  BUY | Held = 94.6188
#     MSFT | Price = 429.44 | Action = -0.2673 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 169.09 | Action = -3.1758 | Trade = HOLD | Held = 0.0000
#     META | Price = 591.82 | Action = -0.2348 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 190.83 | Action = -3.1995 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 259.52 | Action = -4.7875 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 141.22 | Action = -4.3968 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 454: Cash = 0.00, Portfolio = 22187.57
#     AAPL | Price = 229.29 | Action = 1.2904 | Trade = HOLD | Held = 94.6188
#     MSFT | Price = 430.01 | Action = 1.4731 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price = 173.85 | Action = -2.7843 | Trade = HOLD | Held = 0.0000
#     META | Price = 590.34 | Action = 0.3985 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 192.73 | Action = -2.9698 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 257.55 | Action = -5.4464 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 139.31 | Action = -3.7918 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 455: Cash = 0.00, Portfolio = 22175.30
#     AAPL | Price = 225.12 | Action = -0.8931 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 403.99 | Action = -1.9311 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 170.51 | Action = -0.8213 | Trade = HOLD | Held = 0.0000
#     META | Price = 566.18 | Action = 0.1240 | Trade =  BUY | Held = 39.0548
#     AMZN | Price = 186.40 | Action = -1.8564 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 249.85 | Action = -7.4549 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 132.73 | Action = -4.9091 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 456: Cash = 22374.77, Portfolio = 22374.77
#     AAPL | Price = 222.13 | Action = -0.7586 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 407.98 | Action = -0.8399 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 170.69 | Action = -0.8292 | Trade = HOLD | Held = 0.0000
#     META | Price = 565.76 | Action = -0.3046 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 197.93 | Action = -4.3411 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 248.98 | Action = -5.0868 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 135.37 | Action = -2.1626 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 457: Cash = 22374.77, Portfolio = 22374.77
#     AAPL | Price = 221.23 | Action = -0.2439 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 406.08 | Action = -0.3455 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 168.65 | Action = -0.0696 | Trade = HOLD | Held = 0.0000
#     META | Price = 559.30 | Action = -0.0250 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 195.78 | Action = -1.8826 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 242.84 | Action = -4.2435 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 136.02 | Action = -1.3816 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 458: Cash = 0.00, Portfolio = 22374.77
#     AAPL | Price = 222.67 | Action = -0.7183 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 409.07 | Action = 1.5868 | Trade =  BUY | Held = 30.5111
#    GOOGL | Price = 169.15 | Action = 0.6117 | Trade =  BUY | Held = 29.5875
#     META | Price = 571.02 | Action = -0.9247 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 199.50 | Action = 0.5106 | Trade =  BUY | Held = 19.7572
#     TSLA | Price = 251.44 | Action = -4.2993 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 139.88 | Action = -1.7499 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 459: Cash = 0.00, Portfolio = 22746.41
#     AAPL | Price = 221.94 | Action = -0.7280 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 417.73 | Action = -0.7941 | Trade = SELL | Held = 0.0000
#    GOOGL | Price = 175.89 | Action = 0.3098 | Trade = HOLD | Held = 130.9073
#     META | Price = 570.64 | Action = -0.1108 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 207.09 | Action = -2.6493 | Trade = SELL | Held = 0.0000
#     TSLA | Price = 288.53 | Action = -5.9092 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 145.58 | Action = -0.2354 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 460: Cash = 0.00, Portfolio = 22520.73
#     AAPL | Price = 226.68 | Action = -1.2860 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 422.95 | Action = 1.6303 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price = 180.12 | Action = 0.6456 | Trade = HOLD | Held = 130.9073
#     META | Price = 590.24 | Action = 0.2819 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 210.05 | Action = -3.8830 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 296.91 | Action = -4.6142 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 148.85 | Action = 0.5330 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 461: Cash = 0.00, Portfolio = 22790.76
#     AAPL | Price = 226.41 | Action = -1.9804 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 420.08 | Action = -0.8970 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 177.73 | Action = 0.8344 | Trade = HOLD | Held = 130.9073
#     META | Price = 587.89 | Action = -0.6613 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 208.18 | Action = -2.7032 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 321.22 | Action = -4.6895 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 147.60 | Action = 1.5767 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 462: Cash = 0.00, Portfolio = 22903.08
#     AAPL | Price = 223.69 | Action = -3.4179 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 415.58 | Action = 0.3368 | Trade =  BUY | Held = 39.7018
#    GOOGL | Price = 179.72 | Action = -1.0006 | Trade = SELL | Held = 0.0000
#     META | Price = 581.73 | Action = -0.1806 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 206.84 | Action = -3.3577 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 350.00 | Action = -6.4973 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 145.23 | Action = 0.1005 | Trade =  BUY | Held = 37.9221
# ------------------------------------------------------------
# Day 463: Cash = 0.00, Portfolio = 22654.88
#     AAPL | Price = 223.69 | Action = -3.6039 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 420.57 | Action = -0.2894 | Trade = SELL | Held = 0.0000
#    GOOGL | Price = 180.98 | Action = 1.7390 | Trade =  BUY | Held = 50.0864
#     META | Price = 583.38 | Action = -0.9985 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 208.91 | Action = -3.4206 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 328.49 | Action = -7.4618 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 148.26 | Action = 1.5563 | Trade = HOLD | Held = 99.2405
# ------------------------------------------------------------
# Day 464: Cash = 23586.77, Portfolio = 23586.77
#     AAPL | Price = 224.58 | Action = -1.6302 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 422.73 | Action = -2.0170 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 178.25 | Action = -0.2567 | Trade = SELL | Held = 0.0000
#     META | Price = 578.57 | Action = -1.1205 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 214.10 | Action = -5.8587 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 330.24 | Action = -8.7422 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 146.24 | Action = -2.9370 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 465: Cash = 0.00, Portfolio = 23586.77
#     AAPL | Price = 227.67 | Action = -4.4135 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 424.41 | Action = -2.3250 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 174.97 | Action = 0.4666 | Trade =  BUY | Held = 123.1638
#     META | Price = 575.74 | Action = -2.4917 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 211.48 | Action = -6.4218 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 311.18 | Action = -7.3142 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 146.73 | Action = -1.3473 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 466: Cash = 23323.82, Portfolio = 23323.82
#     AAPL | Price = 224.46 | Action = -5.1421 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 412.58 | Action = -3.4884 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 171.89 | Action = -1.0204 | Trade = SELL | Held = 0.0000
#     META | Price = 552.72 | Action = -3.3077 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 202.61 | Action = -7.7816 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 320.72 | Action = -10.2778 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 141.95 | Action = -1.1706 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 467: Cash = 0.00, Portfolio = 23323.82
#     AAPL | Price = 227.47 | Action = -4.9507 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 413.34 | Action = -4.5256 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 174.69 | Action = -1.2222 | Trade = HOLD | Held = 0.0000
#     META | Price = 553.04 | Action = -2.9424 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 201.70 | Action = -5.5664 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 338.74 | Action = -9.4491 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 140.12 | Action = 0.5369 | Trade =  BUY | Held = 176.7241
# ------------------------------------------------------------
# Day 468: Cash = 23039.34, Portfolio = 23039.34
#     AAPL | Price = 227.73 | Action = -3.4034 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 415.36 | Action = -4.9182 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 177.50 | Action = -0.7013 | Trade = HOLD | Held = 0.0000
#     META | Price = 559.71 | Action = -3.7974 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 204.61 | Action = -8.0223 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 346.00 | Action = -8.2109 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 146.98 | Action = -1.3975 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 469: Cash = 0.00, Portfolio = 23039.34
#     AAPL | Price = 228.45 | Action = -4.0433 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 413.07 | Action = -2.0431 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 175.36 | Action = -4.8373 | Trade = HOLD | Held = 0.0000
#     META | Price = 564.13 | Action = -1.6055 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 202.88 | Action = -7.8068 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 342.03 | Action = -9.7058 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 145.86 | Action = 1.4006 | Trade =  BUY | Held = 178.7531
# ------------------------------------------------------------
# Day 470: Cash = 23355.68, Portfolio = 23355.68
#     AAPL | Price = 227.97 | Action = -6.4764 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 411.29 | Action = -5.2028 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 167.04 | Action = -5.9087 | Trade = HOLD | Held = 0.0000
#     META | Price = 561.70 | Action = -4.9117 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 198.38 | Action = -6.7446 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 339.64 | Action = -11.7085 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 146.64 | Action = -0.0812 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 471: Cash = 23355.68, Portfolio = 23355.68
#     AAPL | Price = 229.32 | Action = -4.9611 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 415.40 | Action = -3.8730 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 164.18 | Action = -5.8529 | Trade = HOLD | Held = 0.0000
#     META | Price = 557.76 | Action = -3.6192 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 197.12 | Action = -7.7577 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 352.56 | Action = -10.5864 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 141.92 | Action = -0.6146 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 472: Cash = 0.00, Portfolio = 23355.68
#     AAPL | Price = 232.31 | Action = -5.9029 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 417.19 | Action = -3.5068 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 167.06 | Action = -4.1356 | Trade = HOLD | Held = 0.0000
#     META | Price = 563.72 | Action = -2.0728 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 201.45 | Action = -7.6617 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 338.59 | Action = -11.2349 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 135.99 | Action = 0.3688 | Trade =  BUY | Held = 167.2475
# ------------------------------------------------------------
# Day 473: Cash = 0.00, Portfolio = 23447.66
#     AAPL | Price = 234.49 | Action = -5.9558 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 426.35 | Action = -4.3304 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 168.53 | Action = -4.4285 | Trade = HOLD | Held = 0.0000
#     META | Price = 572.13 | Action = -1.7336 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 207.86 | Action = -7.3130 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 338.23 | Action = -9.5892 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 136.89 | Action = 0.4281 | Trade = HOLD | Held = 167.2475
# ------------------------------------------------------------
# Day 474: Cash = 23399.16, Portfolio = 23399.16
#     AAPL | Price = 234.36 | Action = -5.0842 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 421.37 | Action = -1.4093 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 168.64 | Action = -6.5511 | Trade = HOLD | Held = 0.0000
#     META | Price = 567.80 | Action = -0.4376 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 205.74 | Action = -4.1770 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 332.89 | Action = -8.1920 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 135.31 | Action = -0.4024 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 475: Cash = 23399.16, Portfolio = 23399.16
#     AAPL | Price = 236.76 | Action = -5.3650 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 421.84 | Action = -0.7649 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 168.36 | Action = -4.2467 | Trade = HOLD | Held = 0.0000
#     META | Price = 572.91 | Action = -0.9473 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 207.89 | Action = -5.9364 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 345.16 | Action = -6.5049 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 138.22 | Action = -0.1230 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 476: Cash = 0.00, Portfolio = 23399.16
#     AAPL | Price = 239.01 | Action = -5.4084 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 429.33 | Action = -2.2755 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 170.89 | Action = -3.7902 | Trade = HOLD | Held = 0.0000
#     META | Price = 591.37 | Action = 0.4471 | Trade =  BUY | Held = 39.6421
#     AMZN | Price = 210.71 | Action = -6.2344 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 357.09 | Action = -9.6396 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 138.60 | Action = -0.1272 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 477: Cash = 0.00, Portfolio = 23172.39
#     AAPL | Price = 242.07 | Action = -9.5596 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 429.55 | Action = -2.9670 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 170.74 | Action = -6.6196 | Trade = HOLD | Held = 0.0000
#     META | Price = 612.14 | Action = -0.5481 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 213.44 | Action = -5.7949 | Trade = HOLD | Held = 0.0000
#     TSLA | Price = 351.42 | Action = -10.1868 | Trade = HOLD | Held = 0.0000
#     NVDA | Price = 140.23 | Action = 0.2796 | Trade =  BUY | Held = 172.5827
# ------------------------------------------------------------
#
# Done. Final portfolio value: 23172.39

# %%
bh_env = BuyAndHoldEnvironment(raw_prices)
bh_env.run(start_index=state_dim)

# 3) Final values
print("\nFinal Results:")
print(f"PPO final portfolio:       {env.portfolio_values[-1]:.2f}")
print(f"Buy & Hold final portfolio:{bh_env.portfolio_values[-1]:.2f}")


# 1) Convert dates to datetime explicitly
dates = pd.to_datetime(data[tickers[0]]["dates"])  # ensure it's datetime

# 2) Align the PPO curve to start after `state_dim`
ppo_curve = env.portfolio_values
L_ppo = len(ppo_curve)
ppo_dates = dates[state_dim - 1 : state_dim - 1 + L_ppo]

# 3) Buy & Hold
bh = BuyAndHoldEnvironment(raw_prices)
bh.run(start_index=state_dim)
bh_curve = bh.portfolio_values
L_bh = len(bh_curve)
bh_dates = dates[state_dim - 1 : state_dim - 1 + L_bh]

# 4) Truncate both to the shortest length
min_len = min(len(ppo_dates), len(bh_dates), len(ppo_curve), len(bh_curve))

ppo_dates = ppo_dates[:min_len]
ppo_curve = ppo_curve[:min_len]
bh_dates  = bh_dates[:min_len]
bh_curve  = bh_curve[:min_len]

# 5) Plot
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(ppo_dates, ppo_curve, label="PPO Agent")
ax.plot(bh_dates, bh_curve, 'r--', label="Buy & Hold")

ax.set_title("Portfolio Value vs Buy & Hold")
ax.set_ylabel("Portfolio Value")
ax.legend()
ax.grid(True)

# Format x-axis
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
fig.autofmt_xdate()

plt.tight_layout()
plt.savefig("MLP_CP_DATES_6.png", dpi=600)
plt.show()
# Out:
# Final Results:
# PPO final portfolio:       23172.39
# Buy & Hold final portfolio:35231.80

# %% [markdown]
# ### Run the Environment 50 times to get an average on how the MLP is performing

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pickle
import torch.nn.functional as F
import os

# === Setup ===
tickers = ["AAPL", "MSFT", "GOOGL", "META", "AMZN", "TSLA", "NVDA"]
state_dim = 5
feat_dim = 6
action_dim = 1
n_runs = 20

w1 = torch.nn.Parameter(torch.empty(state_dim * feat_dim, 64))
w2a = torch.nn.Parameter(torch.empty(64, action_dim))
log_std = torch.nn.Parameter(torch.empty(action_dim))


state_dict = torch.load("MLP_Feat_1.pth")
w1.data.copy_(state_dict['w1'])
w2a.data.copy_(state_dict['w2a'])
log_std.data.copy_(state_dict['log_std'])

# === Load Buy & Hold data ===
with open("buyhold_2023_2025.pkl", "rb") as f:
    bh_data = pickle.load(f)
buy_hold_curve = bh_data["curve"]
buy_hold_value = buy_hold_curve[-1]
bh_dates = pd.to_datetime(bh_data["dates"])

# === Run PPO agent ===
final_portfolios = []
ppo_trajectories = []

for run in range(n_runs):
    env = MultiStockEnvironment(data, window_size=state_dim)
    state_dict = env.reset()
    done = False

    while not done:
        actions = {}
        for t in tickers:
            win = state_dict[t]              # shape: (5, 6)
            flat_win = win.flatten()         # shape: (30,)
            st = torch.tensor(flat_win, dtype=torch.float32).view(1, -1)
            with torch.no_grad():
                a_tensor, _ = get_action(st, w1, w2a, log_std)
            actions[t] = a_tensor.item()

        state_dict, _, done, _ = env.step(actions)

    final_value = env.portfolio_values[-1]
    final_portfolios.append(final_value)
    ppo_trajectories.append(env.portfolio_values)
    print(f"Run {run+1:2d}/{n_runs} → Final Portfolio Value: {final_value:.2f}")

# === Summary ===
mean_pf = np.mean(final_portfolios)
std_pf = np.std(final_portfolios)
min_pf = np.min(final_portfolios)
max_pf = np.max(final_portfolios)
beats_bh = sum(p > buy_hold_value for p in final_portfolios)
beat_pct = beats_bh / n_runs * 100

print(f"\nSummary over {n_runs} runs:")
print(f"→ Mean Final Portfolio: {mean_pf:.2f} ± {std_pf:.2f}")
print(f"→ Min: {min_pf:.2f}, Max: {max_pf:.2f}")
print(f"→ Buy & Hold Final Portfolio: {buy_hold_value:.2f}")
print(f"→ PPO Agent beat Buy & Hold in {beat_pct:.1f}% of runs ({beats_bh}/{n_runs})")

# === Histogram ===
plt.figure(figsize=(8, 4))
plt.hist(final_portfolios, bins=10, edgecolor='k', alpha=0.7)
plt.axvline(buy_hold_value, color='r', linestyle='--', linewidth=2,
            label=f'Buy & Hold = {buy_hold_value:.2f}')
plt.title("Distribution of Final Portfolio Values (PPO Agent – MLP + Features)")
plt.xlabel("Final Portfolio Value")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Trajectory plot ===
ppo_array = np.array(ppo_trajectories)
median_curve = np.median(ppo_array, axis=0)
std_curve = np.std(ppo_array, axis=0)

x_dates = bh_dates[state_dim - 1:state_dim - 1 + len(median_curve)]
min_len = min(len(x_dates), len(median_curve), len(buy_hold_curve))
x_dates = x_dates[:min_len]
median_curve = median_curve[:min_len]
std_curve = std_curve[:min_len]
buy_hold_curve = buy_hold_curve[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(x_dates, median_curve, label='PPO Median', linewidth=2)
plt.fill_between(x_dates, median_curve - std_curve, median_curve + std_curve,
                 color='skyblue', alpha=0.4, label='Std Dev')
plt.plot(x_dates, buy_hold_curve, 'r--', label='Buy & Hold')

plt.title("MLP (Features): Median Portfolio Value with Standard Deviation on Test Data")
plt.ylabel("Portfolio Value ($)")
plt.xlabel("Date")
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/977285639.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load("MLP_Feat_1.pth")
# Run  1/20 → Final Portfolio Value: 34674.52
# Run  2/20 → Final Portfolio Value: 41894.22
# Run  3/20 → Final Portfolio Value: 44973.24
# Run  4/20 → Final Portfolio Value: 32106.00
# Run  5/20 → Final Portfolio Value: 39630.27
# Run  6/20 → Final Portfolio Value: 51769.60
# Run  7/20 → Final Portfolio Value: 54103.35
# Run  8/20 → Final Portfolio Value: 45971.49
# Run  9/20 → Final Portfolio Value: 40203.69
# Run 10/20 → Final Portfolio Value: 46398.59
# Run 11/20 → Final Portfolio Value: 46918.35
# Run 12/20 → Final Portfolio Value: 39955.55
# Run 13/20 → Final Portfolio Value: 39831.98
# Run 14/20 → Final Portfolio Value: 37490.11
# Run 15/20 → Final Portfolio Value: 48399.15
# Run 16/20 → Final Portfolio Value: 44854.74
# Run 17/20 → Final Portfolio Value: 53843.17
# Run 18/20 → Final Portfolio Value: 51168.07
# Run 19/20 → Final Portfolio Value: 59194.97
# Run 20/20 → Final Portfolio Value: 39134.48
#
# Summary over 20 runs:
# → Mean Final Portfolio: 44625.78 ± 6852.41
# → Min: 32106.00, Max: 59194.97
# → Buy & Hold Final Portfolio: 28420.93
# → PPO Agent beat Buy & Hold in 100.0% of runs (20/20)

# %% [markdown]
# ### test on unseen data

# %%
import yfinance as yf
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import os
import pickle

tickers = ["AAPL", "MSFT", "GOOGL", "META", "AMZN", "TSLA", "NVDA"]
start, end = "2025-01-01", "2025-06-01"
initial_cash = 10000.0
state_dim = 5
n_runs = 200

w1 = torch.nn.Parameter(torch.empty(state_dim * feat_dim, hidden_dim))  # [30, 64]
w2a = torch.nn.Parameter(torch.empty(hidden_dim, action_dim))           # [64, 1]
log_std = torch.nn.Parameter(torch.zeros(action_dim))                   # [1]

# Load saved weights
state_dict = torch.load("MLP_Feat_2.pth")
w1.data.copy_(state_dict["w1"])
w2a.data.copy_(state_dict["w2a"])
log_std.data.copy_(state_dict["log_std"])

# === Load test Buy & Hold curve ===
with open("buyhold_2025_2025.pkl", "rb") as f:
    bh_data = pickle.load(f)
buy_hold_curve = bh_data["curve"]
bh_final = buy_hold_curve[-1]
bh_dates = pd.to_datetime(bh_data["dates"])

# === Prepare test data with full features ===
data_test = {}
for t in tickers:
    df = yf.download(t, start=start, end=end)
    closes = df["Close"].astype(np.float32)
    mu, sigma = closes.mean(), closes.std()
    norm = (closes - mu) / sigma

    ema = closes.ewm(span=5).mean().astype(np.float32)
    delta = closes.diff()
    gain = delta.clip(lower=0).rolling(14).mean()
    loss = -delta.clip(upper=0).rolling(14).mean()
    rs = gain / loss
    rsi = (100 - 100 / (1 + rs)).astype(np.float32)
    ema12 = closes.ewm(span=12).mean()
    ema26 = closes.ewm(span=26).mean()
    macd = (ema12 - ema26).astype(np.float32)
    mbb = closes.rolling(20).mean()
    mbb_sd = closes.rolling(20).std()
    bb_upper = (mbb + 2 * mbb_sd).astype(np.float32)
    bb_lower = (mbb - 2 * mbb_sd).astype(np.float32)

    data_test[t] = {
        "dates": df.index,
        "raw": closes.values,
        "norm": norm.values,
        "ema": ema.values,
        "rsi": rsi.values,
        "macd": macd.values,
        "bb_upper": bb_upper.values,
        "bb_lower": bb_lower.values,
    }

# Drop NaNs
for t in tickers:
    feat_stack = np.column_stack([
        data_test[t]["norm"],
        data_test[t]["ema"],
        data_test[t]["rsi"],
        data_test[t]["macd"],
        data_test[t]["bb_upper"],
        data_test[t]["bb_lower"],
    ])
    valid_rows = ~np.isnan(feat_stack).any(axis=1)
    start_idx = np.argmax(valid_rows)
    for key in data_test[t]:
        data_test[t][key] = data_test[t][key][start_idx:]

# Normalize features
for t in tickers:
    for feat in ["ema", "rsi", "macd", "bb_upper", "bb_lower"]:
        arr = data_test[t][feat]
        mu, sigma = arr.mean(), arr.std()
        data_test[t][feat] = (arr - mu) / sigma

# === PPO Evaluation ===
final_pf = []
ppo_trajectories = []

print("Running PPO (MLP + Features) on Test Data...\n")

for run in range(n_runs):
    env = MultiStockEnvironment(data_test, window_size=state_dim)
    state_dict = env.reset()
    done = False
    trajectory = [env.initial_cash]

    while not done:
        actions = {}
        for t in tickers:
            win = state_dict[t]
            flat = win.flatten()
            st = torch.tensor(flat, dtype=torch.float32).view(1, -1)
            a = get_action(st, w1, w2a, log_std)[0].item()
            actions[t] = a

        state_dict, pv, done, _ = env.step(actions)
        trajectory.append(pv)

    final_val = trajectory[-1]
    final_pf.append(final_val)
    ppo_trajectories.append(trajectory)
    print(f"Run {run+1:3d}/{n_runs} → Final Value: {final_val:.2f}")

# === Pad PPO trajectories and align Buy & Hold ===
max_len = max(len(p) for p in ppo_trajectories)
for i in range(n_runs):
    last = ppo_trajectories[i][-1]
    ppo_trajectories[i] += [last] * (max_len - len(ppo_trajectories[i]))

ppo_array = np.array(ppo_trajectories)
mean_curve = np.mean(ppo_array, axis=0)
std_curve  = np.std(ppo_array, axis=0)

# === Summary ===
mean_pf = np.mean(final_pf)
std_pf = np.std(final_pf)
beats = sum(p > bh_final for p in final_pf)
bh_return = (bh_final / initial_cash - 1) * 100

print(f"\n=== PPO on Unseen Data (MLP + Features) ===")
print(f"Runs: {n_runs}")
print(f"→ Final Portfolio: mean {mean_pf:.2f} ±{std_pf:.2f}")
print(f"→ Min: {np.min(final_pf):.2f}, Max: {np.max(final_pf):.2f}")
print(f"→ Buy & Hold Final Portfolio: {bh_final:.2f}")
print(f"→ PPO beats Buy & Hold in {beats}/{n_runs} runs ({beats/n_runs*100:.1f}%)")

def annualized_return(final, initial, years=1):
    return ((final / initial) ** (1 / years) - 1) * 100

print(f"→ PPO Annualized Return: {annualized_return(mean_pf, initial_cash):.2f}%")
print(f"→ Buy & Hold Return:      {annualized_return(bh_final, initial_cash):.2f}%")

# === Histogram ===
plt.figure(figsize=(6, 4))
plt.hist(final_pf, bins=10, edgecolor='k', alpha=0.7)
plt.axvline(bh_final, color='r', linestyle='--', linewidth=2, label='Buy & Hold')
plt.title("MLP + Features: Final Portfolio Distribution (Test Data)")
plt.xlabel("Final Portfolio Value")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
#plt.savefig("MLP_Features/UNSEEN_hist.png", dpi=600)
plt.show()

# === Median ± Std Dev plot ===
x_dates = bh_dates[state_dim - 1 : state_dim - 1 + max_len]
min_len = min(len(x_dates), len(mean_curve), len(buy_hold_curve))
x_dates = x_dates[:min_len]
mean_curve = mean_curve[:min_len]
std_curve = std_curve[:min_len]
buy_hold_curve = buy_hold_curve[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(x_dates, mean_curve, label="PPO Mean", linewidth=2)
plt.fill_between(x_dates, mean_curve - std_curve, mean_curve + std_curve,
                 color='skyblue', alpha=0.4, label='Std Dev')
plt.plot(x_dates, buy_hold_curve, 'r--', label=f'Buy & Hold = {bh_final:.2f}')
plt.title("MLP with Features: Test Set Portfolio Evaluation")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load("MLP_Feat_2.pth")
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_3908/975425311.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(t, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# Running PPO (MLP + Features) on Test Data...
#
# Run   1/200 → Final Value: 10822.57
# Run   2/200 → Final Value: 9547.48
# Run   3/200 → Final Value: 12049.69
# Run   4/200 → Final Value: 11079.59
# Run   5/200 → Final Value: 10151.14
# Run   6/200 → Final Value: 9813.07
# Run   7/200 → Final Value: 8966.25
# Run   8/200 → Final Value: 9975.32
# Run   9/200 → Final Value: 11838.51
# Run  10/200 → Final Value: 11173.28
# Run  11/200 → Final Value: 11264.85
# Run  12/200 → Final Value: 10583.46
# Run  13/200 → Final Value: 10879.59
# Run  14/200 → Final Value: 8903.49
# Run  15/200 → Final Value: 9687.55
# Run  16/200 → Final Value: 9095.44
# Run  17/200 → Final Value: 10457.95
# Run  18/200 → Final Value: 8629.96
# Run  19/200 → Final Value: 10881.39
# Run  20/200 → Final Value: 11848.70
# Run  21/200 → Final Value: 9812.05
# Run  22/200 → Final Value: 9581.27
# Run  23/200 → Final Value: 10035.80
# Run  24/200 → Final Value: 9444.47
# Run  25/200 → Final Value: 9542.28
# Run  26/200 → Final Value: 10145.69
# Run  27/200 → Final Value: 8517.12
# Run  28/200 → Final Value: 13125.12
# Run  29/200 → Final Value: 8628.50
# Run  30/200 → Final Value: 10618.30
# Run  31/200 → Final Value: 7901.83
# Run  32/200 → Final Value: 10332.83
# Run  33/200 → Final Value: 9782.01
# Run  34/200 → Final Value: 11102.20
# Run  35/200 → Final Value: 10409.50
# Run  36/200 → Final Value: 12224.86
# Run  37/200 → Final Value: 8947.63
# Run  38/200 → Final Value: 10587.54
# Run  39/200 → Final Value: 12203.53
# Run  40/200 → Final Value: 11042.92
# Run  41/200 → Final Value: 10497.22
# Run  42/200 → Final Value: 9992.99
# Run  43/200 → Final Value: 8925.57
# Run  44/200 → Final Value: 9236.04
# Run  45/200 → Final Value: 9164.97
# Run  46/200 → Final Value: 9800.87
# Run  47/200 → Final Value: 10319.49
# Run  48/200 → Final Value: 12635.79
# Run  49/200 → Final Value: 10816.08
# Run  50/200 → Final Value: 11294.95
# Run  51/200 → Final Value: 14235.34
# Run  52/200 → Final Value: 9522.98
# Run  53/200 → Final Value: 10435.81
# Run  54/200 → Final Value: 12647.58
# Run  55/200 → Final Value: 10422.22
# Run  56/200 → Final Value: 10965.19
# Run  57/200 → Final Value: 10089.45
# Run  58/200 → Final Value: 10149.79
# Run  59/200 → Final Value: 10181.62
# Run  60/200 → Final Value: 13295.94
# Run  61/200 → Final Value: 10352.59
# Run  62/200 → Final Value: 9592.72
# Run  63/200 → Final Value: 9592.36
# Run  64/200 → Final Value: 10455.90
# Run  65/200 → Final Value: 9012.79
# Run  66/200 → Final Value: 9473.68
# Run  67/200 → Final Value: 9211.65
# Run  68/200 → Final Value: 8969.35
# Run  69/200 → Final Value: 9859.39
# Run  70/200 → Final Value: 9848.12
# Run  71/200 → Final Value: 8398.83
# Run  72/200 → Final Value: 10715.48
# Run  73/200 → Final Value: 10937.32
# Run  74/200 → Final Value: 11669.88
# Run  75/200 → Final Value: 10364.00
# Run  76/200 → Final Value: 9169.33
# Run  77/200 → Final Value: 12092.79
# Run  78/200 → Final Value: 9155.84
# Run  79/200 → Final Value: 9744.13
# Run  80/200 → Final Value: 10547.65
# Run  81/200 → Final Value: 10850.58
# Run  82/200 → Final Value: 7786.73
# Run  83/200 → Final Value: 8411.48
# Run  84/200 → Final Value: 8995.51
# Run  85/200 → Final Value: 10220.95
# Run  86/200 → Final Value: 13461.46
# Run  87/200 → Final Value: 12792.95
# Run  88/200 → Final Value: 13711.06
# Run  89/200 → Final Value: 8578.14
# Run  90/200 → Final Value: 10257.26
# Run  91/200 → Final Value: 8901.63
# Run  92/200 → Final Value: 8883.44
# Run  93/200 → Final Value: 10511.51
# Run  94/200 → Final Value: 10559.46
# Run  95/200 → Final Value: 9732.17
# Run  96/200 → Final Value: 9985.14
# Run  97/200 → Final Value: 11202.85
# Run  98/200 → Final Value: 10046.60
# Run  99/200 → Final Value: 7240.59
# Run 100/200 → Final Value: 7895.15
# Run 101/200 → Final Value: 9853.76
# Run 102/200 → Final Value: 9471.30
# Run 103/200 → Final Value: 9504.63
# Run 104/200 → Final Value: 10408.92
# Run 105/200 → Final Value: 10517.53
# Run 106/200 → Final Value: 8929.44
# Run 107/200 → Final Value: 9784.46
# Run 108/200 → Final Value: 11708.80
# Run 109/200 → Final Value: 9738.93
# Run 110/200 → Final Value: 10343.42
# Run 111/200 → Final Value: 9763.66
# Run 112/200 → Final Value: 10626.54
# Run 113/200 → Final Value: 10977.56
# Run 114/200 → Final Value: 11050.58
# Run 115/200 → Final Value: 10517.52
# Run 116/200 → Final Value: 10225.47
# Run 117/200 → Final Value: 9555.75
# Run 118/200 → Final Value: 11909.23
# Run 119/200 → Final Value: 9928.61
# Run 120/200 → Final Value: 10783.44
# Run 121/200 → Final Value: 9573.45
# Run 122/200 → Final Value: 10625.24
# Run 123/200 → Final Value: 8920.42
# Run 124/200 → Final Value: 8856.02
# Run 125/200 → Final Value: 9921.89
# Run 126/200 → Final Value: 10220.90
# Run 127/200 → Final Value: 9389.87
# Run 128/200 → Final Value: 11750.38
# Run 129/200 → Final Value: 11154.29
# Run 130/200 → Final Value: 8067.45
# Run 131/200 → Final Value: 9993.45
# Run 132/200 → Final Value: 9666.73
# Run 133/200 → Final Value: 12306.58
# Run 134/200 → Final Value: 9350.96
# Run 135/200 → Final Value: 10936.79
# Run 136/200 → Final Value: 9661.04
# Run 137/200 → Final Value: 11578.19
# Run 138/200 → Final Value: 9084.40
# Run 139/200 → Final Value: 9053.92
# Run 140/200 → Final Value: 8421.15
# Run 141/200 → Final Value: 9570.80
# Run 142/200 → Final Value: 12193.98
# Run 143/200 → Final Value: 10596.39
# Run 144/200 → Final Value: 12013.61
# Run 145/200 → Final Value: 9372.80
# Run 146/200 → Final Value: 9543.39
# Run 147/200 → Final Value: 9210.41
# Run 148/200 → Final Value: 8710.35
# Run 149/200 → Final Value: 13814.15
# Run 150/200 → Final Value: 10830.91
# Run 151/200 → Final Value: 10955.97
# Run 152/200 → Final Value: 11348.66
# Run 153/200 → Final Value: 9137.81
# Run 154/200 → Final Value: 11976.08
# Run 155/200 → Final Value: 10624.38
# Run 156/200 → Final Value: 9801.20
# Run 157/200 → Final Value: 8473.25
# Run 158/200 → Final Value: 8835.68
# Run 159/200 → Final Value: 9799.58
# Run 160/200 → Final Value: 10127.50
# Run 161/200 → Final Value: 8898.19
# Run 162/200 → Final Value: 10153.31
# Run 163/200 → Final Value: 7250.21
# Run 164/200 → Final Value: 10867.38
# Run 165/200 → Final Value: 10191.37
# Run 166/200 → Final Value: 9170.83
# Run 167/200 → Final Value: 10326.90
# Run 168/200 → Final Value: 10676.76
# Run 169/200 → Final Value: 10471.48
# Run 170/200 → Final Value: 8567.86
# Run 171/200 → Final Value: 9383.72
# Run 172/200 → Final Value: 11132.21
# Run 173/200 → Final Value: 11292.25
# Run 174/200 → Final Value: 10118.08
# Run 175/200 → Final Value: 11815.40
# Run 176/200 → Final Value: 9576.84
# Run 177/200 → Final Value: 9800.53
# Run 178/200 → Final Value: 8371.54
# Run 179/200 → Final Value: 10013.87
# Run 180/200 → Final Value: 11171.20
# Run 181/200 → Final Value: 9537.01
# Run 182/200 → Final Value: 10935.88
# Run 183/200 → Final Value: 9877.58
# Run 184/200 → Final Value: 9051.66
# Run 185/200 → Final Value: 10069.72
# Run 186/200 → Final Value: 9389.95
# Run 187/200 → Final Value: 9885.07
# Run 188/200 → Final Value: 7631.71
# Run 189/200 → Final Value: 10812.70
# Run 190/200 → Final Value: 10793.06
# Run 191/200 → Final Value: 9715.68
# Run 192/200 → Final Value: 9847.83
# Run 193/200 → Final Value: 11813.54
# Run 194/200 → Final Value: 9733.60
# Run 195/200 → Final Value: 9828.40
# Run 196/200 → Final Value: 9108.82
# Run 197/200 → Final Value: 10725.74
# Run 198/200 → Final Value: 7985.03
# Run 199/200 → Final Value: 10886.74
# Run 200/200 → Final Value: 9377.58
#
# === PPO on Unseen Data (MLP + Features) ===
# Runs: 200
# → Final Portfolio: mean 10163.90 ±1222.55
# → Min: 7240.59, Max: 14235.34
# → Buy & Hold Final Portfolio: 9594.51
# → PPO beats Buy & Hold in 132/200 runs (66.0%)
# → PPO Annualized Return: 1.64%
# → Buy & Hold Return:      -4.05%
